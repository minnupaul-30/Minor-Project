# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import import_ipynb
#import Segmentation
import time
import preds
# Out:
# importing Jupyter notebook from preds.ipynb

# %%
CATEGORIES = set()
names =[]
for i in os.listdir('testing/'):
    names.append(i.split('.')[0])
for i in names:
    for x in list(i):
        CATEGORIES.add(x)
CATEGORIES=list(CATEGORIES)
print(CATEGORIES)
# Out:
# ['M', 'H', 'F', 'D', 'G', '9', 'N', 'Q', 'U', '7', 'Y', 'K', 'W', 'T', '1', '5', 'C', '2', '8', 'B', 'L', 'P', 'E', 'R', '4', 'V', 'A', '3', '6', 'S', 'Z', 'X', 'J']

# %%
print(len(train_data))

# %%
import random

random.shuffle(train_data)

# %%
for sample in train_data[:10]:
    print(sample[1])

# %%
X = []
y = []

# %%
for features, label in train_data:
    X.append(features)
    y.append(label)
    
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
import pickle

pickle_out = open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()
pickle_out = open("y.pickle", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
pickle_in= open("X.pickle", "rb")
X = pickle.load(pickle_in)
X.shape[1:]

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout,Activation, Flatten, Conv2D, MaxPooling2D

X = pickle.load(open("X.pickle","rb"))
y = pickle.load(open("y.pickle","rb"))

X = X/255.0

model = Sequential()

model.add(Conv2D(64,(3,3),input_shape= X.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation("relu"))


model.add(Dense(19))
model.add(Activation("softmax"))

from keras.utils import to_categorical
y_binary = to_categorical(y)

model.compile(loss="categorical_crossentropy",
             optimizer="adam",
             metrics=['accuracy'])

model.fit(X,y_binary,batch_size=128, epochs=20, validation_split = 0.2)

# %%
#loss_value, metrics_value = model.evaluate(X,y_binary,batch_size=10)

# %%
#print(loss_value, metrics_value)

# %%
import random

# %%
def similarity(a,b):
    i =0
    for x,y in zip(a,b):
        if x==y:
            i+= 1
    percentage = (i/5) * 100
    return percentage

def prepare(filepath):
    IMG_SIZE = 50
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
    #plt.imshow(new_array,'gray')
    return new_array.reshape(-1, IMG_SIZE,IMG_SIZE,1)

total_time = 0
score = 0
count = 0
done = []
list_ = preds.predictions('testing',CATEGORIES)
CAPTCHA_DIR = list_[0]
for x in CAPTCHA_DIR:
    captchas = random.choice(CAPTCHA_DIR)
    if captchas in done:
        continue
    else:
        done.append(captchas)
        start_time = time.time()
        predict_list= []
        print('\n')
        print('Actual: ',captchas[0][0])

        files = []
        for segments in list_:
            files.append(segments)

        #for segments in files:
        #    filepath = (SEGMENTS_DIR,segments)
        #    prediction = model.predict([prepare(filepath)])
        #    predict_list.append(CATEGORIES[np.argmax(prediction[0])])

        elapsed_time = time.time()-start_time
        time.sleep(captchas[1])
        total_time += elapsed_time
        final_prediction = ''.join(predict_list)
        #if captcha_name[0]== final_prediction:
        #    score +=1
        score = list_[1]
        print('Predicted:',captchas[0][1],'\n')
        print('Elapsed time= ',captchas[1],'s')
        total_time +=captchas[1]
        print('<------------------------------->')    
    

print('Total number of CAPTCHAS broken: ',score)    
print('Total number of CAPTCHAS attempted: ',len(list_[0]))
print('Total time taken= ',total_time,'s')
print('Accuracy= ', (score/len(list_[0])*100))
#model = tf.keras.models.load_model('captcha_alpha.model')
#prediction = model.predict([prepare('3.png')])
#print(len(prediction[0]))
#print(prediction[0])
#print(CATEGORIES[np.argmax(prediction[0])])
# Out:
# Actual:  BA5E
# Predicted: BA5E
#
# Elapsed time=  0.06536952025343168 s
# <------------------------------->
#
#
# Actual:  7GPX2
# Predicted: 1G8G
#
# Elapsed time=  0.6487170167269833 s
# <------------------------------->
#
#
# Actual:  2DWR
# Predicted: 2DWR
#
# Elapsed time=  0.5530532659827199 s
# <------------------------------->
#
#
# Actual:  RNQWJ
# Predicted: RNQWJ
#
# Elapsed time=  0.4001912331995743 s
# <------------------------------->
#
#
# Actual:  L9B8
# Predicted: L9B8
#
# Elapsed time=  0.7046653080768306 s
# <------------------------------->
#
#
# Actual:  R8ECB
# Predicted: R8ECB
#
# Elapsed time=  0.5760432324970365 s
# <------------------------------->
#
#
# Actual:  6GD6Q
# Predicted: 6GD6Q
#
# Elapsed time=  0.46679020367625157 s
# <------------------------------->
#
#
# Actual:  GB3J
# Predicted: GB3J
#
# Elapsed time=  0.4599725212814352 s
# <------------------------------->
#
#
# Actual:  X1MX
# Predicted: X1MX
#
# Elapsed time=  0.33641761629238354 s
# <------------------------------->
#
#
# Actual:  94H5F
# Predicted: 8WJW
#
# Elapsed time=  0.4396761946618446 s
# <------------------------------->
#
#
# Actual:  WNDQV
# Predicted: 25C1
#
# Elapsed time=  0.4310695166075744 s
# <------------------------------->
#
#
# Actual:  HL4W
# Predicted: 8MAH
#
# Elapsed time=  0.17220955097351986 s
# <------------------------------->
#
#
# Actual:  P3NJM
# Predicted: P3NJM
#
# Elapsed time=  0.8110663289351915 s
# <------------------------------->
#
#
# Actual:  Q4KXA
# Predicted: Q4KXA
#
# Elapsed time=  0.6506158406797067 s
# <------------------------------->
#
#
# Actual:  G8MUM
# Predicted: G8MUM
#
# Elapsed time=  0.41109891184796066 s
# <------------------------------->
#
#
# Actual:  PXPS
# Predicted: PXPS
#
# Elapsed time=  0.776545947567206 s
# <------------------------------->
#
#
# Actual:  PGBZP
# Predicted: PGBZP
#
# Elapsed time=  0.34918879020476223 s
# <------------------------------->
#
#
# Actual:  QDQ5
# Predicted: KVUC
#
# Elapsed time=  0.2907069206754661 s
# <------------------------------->
#
#
# Actual:  XJLV3
# Predicted: XJLV3
#
# Elapsed time=  0.11182145817762423 s
# <------------------------------->
#
#
# Actual:  KMX5
# Predicted: KMX5
#
# Elapsed time=  0.395188456653749 s
# <------------------------------->
#
#
# Actual:  M5CD
# Predicted: M5CD
#
# Elapsed time=  0.5685839581383724 s
# <------------------------------->
#
#
# Actual:  QKEVE
# Predicted: XPT7
#
# Elapsed time=  0.6149611087316993 s
# <------------------------------->
#
#
# Actual:  DMY4V
# Predicted: DMY4V
#
# Elapsed time=  0.45171755838155747 s
# <------------------------------->
#
#
# Actual:  7HNAU
# Predicted: 7HNAU
#
# Elapsed time=  0.013858903192524363 s
# <------------------------------->
#
#
# Actual:  XBTJA
# Predicted: NWEW
#
# Elapsed time=  0.09070072443567112 s
# <------------------------------->
#
#
# Actual:  AX17
# Predicted: AX17
#
# Elapsed time=  0.2623965210405129 s
# <------------------------------->
#
#
# Actual:  WTUA9
# Predicted: WTUA9
#
# Elapsed time=  0.3603462599915366 s
# <------------------------------->
#
#
# Actual:  CESX2
# Predicted: 38P8
#
# Elapsed time=  0.15168441456509574 s
# <------------------------------->
#
#
# Actual:  JNAA
# Predicted: YKSA
#
# Elapsed time=  0.8161223132713488 s
# <------------------------------->
#
#
# Actual:  GLZC
# Predicted: BDQH
#
# Elapsed time=  0.5061639079837756 s
# <------------------------------->
#
#
# Actual:  Q254
# Predicted: WLPX
#
# Elapsed time=  0.9725688065909386 s
# <------------------------------->
#
#
# Actual:  M8Z3
# Predicted: UZ2C
#
# Elapsed time=  0.5686917895224546 s
# <------------------------------->
#
#
# Actual:  3XHJ
# Predicted: 3XHJ
#
# Elapsed time=  0.7068743030887955 s
# <------------------------------->
#
#
# Actual:  JHNG2
# Predicted: JHNG2
#
# Elapsed time=  0.08786197094035597 s
# <------------------------------->
#
#
# Actual:  QE3BK
# Predicted: QE3BK
#
# Elapsed time=  0.2407184507299478 s
# <------------------------------->
#
#
# Actual:  DCWGS
# Predicted: DCWGS
#
# Elapsed time=  0.22221110738634087 s
# <------------------------------->
#
#
# Actual:  SLAE
# Predicted: 27VZ
#
# Elapsed time=  0.5451930969922975 s
# <------------------------------->
#
#
# Actual:  6JGW
# Predicted: 6JGW
#
# Elapsed time=  0.7389019655152697 s
# <------------------------------->
#
#
# Actual:  YMLU
# Predicted: YMLU
#
# Elapsed time=  0.3772719521911705 s
# <------------------------------->
#
#
# Actual:  XNPQ
# Predicted: 8XP7
#
# Elapsed time=  0.5078109971191752 s
# <------------------------------->
#
#
# Actual:  AAXH
# Predicted: AAXH
#
# Elapsed time=  0.8478947468228089 s
# <------------------------------->
#
#
# Actual:  EK1MJ
# Predicted: QS2R
#
# Elapsed time=  0.09727720395766803 s
# <------------------------------->
#
#
# Actual:  32QW
# Predicted: DA6S
#
# Elapsed time=  0.024751738154683456 s
# <------------------------------->
#
#
# Actual:  9PG93
# Predicted: JGS8
#
# Elapsed time=  0.3178639428144161 s
# <------------------------------->
#
#
# Actual:  EESTM
# Predicted: EESTM
#
# Elapsed time=  0.3929622238444067 s
# <------------------------------->
#
#
# Actual:  GXSH
# Predicted: GXSH
#
# Elapsed time=  0.066083982919109 s
# <------------------------------->
#
#
# Actual:  CT4FM
# Predicted: CT4FM
#
# Elapsed time=  0.20022334867089298 s
# <------------------------------->
#
#
# Actual:  ALMRS
# Predicted: ALMRS
#
# Elapsed time=  0.06648822023153889 s
# <------------------------------->
#
#
# Actual:  HL4W
# Predicted: HL4W
#
# Elapsed time=  0.6806149855743949 s
# <------------------------------->
#
#
# Actual:  DMY4V
# Predicted: VSGM
#
# Elapsed time=  0.43049311559503023 s
# <------------------------------->
#
#
# Actual:  MF7DA
# Predicted: MF7DA
#
# Elapsed time=  0.797778322982067 s
# <------------------------------->
#
#
# Actual:  HU67D
# Predicted: HU67D
#
# Elapsed time=  0.5248459586572316 s
# <------------------------------->
#
#
# Actual:  1S6WE
# Predicted: 4CLS
#
# Elapsed time=  0.8765757819495028 s
# <------------------------------->
#
#
# Actual:  FJ5TR
# Predicted: FJ5TR
#
# Elapsed time=  0.9539606620982449 s
# <------------------------------->
#
#
# Actual:  9314
# Predicted: 9314
#
# Elapsed time=  0.9026505121342564 s
# <------------------------------->
#
#
# Actual:  YXFG
# Predicted: YXFG
#
# Elapsed time=  0.20829436358310238 s
# <------------------------------->
#
#
# Actual:  Q254
# Predicted: Q254
#
# Elapsed time=  0.5182398387095364 s
# <------------------------------->
#
#
# Actual:  M5CD
# Predicted: WVSY
#
# Elapsed time=  0.25594135550978725 s
# <------------------------------->
#
#
# Actual:  PQYZZ
# Predicted: 6ALD
#
# Elapsed time=  0.4153107293014421 s
# <------------------------------->
#
#
# Actual:  YES2
# Predicted: YES2
#
# Elapsed time=  0.19873956271433701 s
# <------------------------------->
#
#
# Actual:  UEVH
# Predicted: CRSS
#
# Elapsed time=  0.9048588096395771 s
# <------------------------------->
#
#
# Actual:  UBWU7
# Predicted: 8PG4
#
# Elapsed time=  0.4129103121191614 s
# <------------------------------->
#
#
# Actual:  GXSH
# Predicted: GXSH
#
# Elapsed time=  0.46799657643215853 s
# <------------------------------->
#
#
# Actual:  C7DY
# Predicted: C7DY
#
# Elapsed time=  0.9324694804726423 s
# <------------------------------->
#
#
# Actual:  EG7XZ
# Predicted: EG7XZ
#
# Elapsed time=  0.27549440229951017 s
# <------------------------------->
#
#
# Actual:  32C81
# Predicted: 32C81
#
# Elapsed time=  0.10103892887502997 s
# <------------------------------->
#
#
# Actual:  DMFV
# Predicted: DMFV
#
# Elapsed time=  0.7127673930181359 s
# <------------------------------->
#
#
# Actual:  GV18Q
# Predicted: G1TR
#
# Elapsed time=  0.25458951653379935 s
# <------------------------------->
#
#
# Actual:  4FR5K
# Predicted: 4FR5K
#
# Elapsed time=  0.20473006889849255 s
# <------------------------------->
#
#
# Actual:  4BQS
# Predicted: 4BQS
#
# Elapsed time=  0.6908445392485953 s
# <------------------------------->
#
#
# Actual:  FTR4N
# Predicted: FTR4N
#
# Elapsed time=  0.9809166211421466 s
# <------------------------------->
#
#
# Actual:  J3V5X
# Predicted: J3V5X
#
# Elapsed time=  0.0849899655781462 s
# <------------------------------->
#
#
# Actual:  1C2D
# Predicted: 1C2D
#
# Elapsed time=  0.26933805937850996 s
# <------------------------------->
#
#
# Actual:  32C81
# Predicted: 989U
#
# Elapsed time=  0.555287653303373 s
# <------------------------------->
#
#
# Actual:  WTUA9
# Predicted: WTUA9
#
# Elapsed time=  0.4657611236178707 s
# <------------------------------->
#
#
# Actual:  AAXH
# Predicted: DG8A
#
# Elapsed time=  0.9902185370289516 s
# <------------------------------->
#
#
# Actual:  X12K
# Predicted: X12K
#
# Elapsed time=  0.8785661052375275 s
# <------------------------------->
#
#
# Actual:  6L837
# Predicted: QLYY
#
# Elapsed time=  0.46930624528506193 s
# <------------------------------->
#
#
# Actual:  C1ALS
# Predicted: YJ73
#
# Elapsed time=  0.9748313278740675 s
# <------------------------------->
#
#
# Actual:  6GD6Q
# Predicted: 6GD6Q
#
# Elapsed time=  0.7079776057491954 s
# <------------------------------->
#
#
# Actual:  L914
# Predicted: 7LFK
#
# Elapsed time=  0.09070775044666968 s
# <------------------------------->
#
#
# Actual:  ZUB5
# Predicted: ZUB5
#
# Elapsed time=  0.9697979147344479 s
# <------------------------------->
#
#
# Actual:  KSHL
# Predicted: KSHL
#
# Elapsed time=  0.8488187468661088 s
# <------------------------------->
#
#
# Actual:  1K83
# Predicted: 6MQE
#
# Elapsed time=  0.5497282050597183 s
# <------------------------------->
#
#
# Actual:  2PRQS
# Predicted: 2PRQS
#
# Elapsed time=  0.5906581707001074 s
# <------------------------------->
#
#
# Actual:  9RUH4
# Predicted: 9RUH4
#
# Elapsed time=  0.023916163453536088 s
# <------------------------------->
#
#
# Actual:  5W8GB
# Predicted: BYBC
#
# Elapsed time=  0.4131135009357402 s
# <------------------------------->
#
#
# Actual:  2Z9SX
# Predicted: 9L35
#
# Elapsed time=  0.45149026343678744 s
# <------------------------------->
#
#
# Actual:  ADKB8
# Predicted: ADKB8
#
# Elapsed time=  0.23173403065950327 s
# <------------------------------->
#
#
# Actual:  AX17
# Predicted: AX17
#
# Elapsed time=  0.6531792585010767 s
# <------------------------------->
#
#
# Actual:  2W862
# Predicted: BL75
#
# Elapsed time=  0.8196519878299852 s
# <------------------------------->
#
#
# Actual:  1GKX
# Predicted: EWZS
#
# Elapsed time=  0.08776467613605043 s
# <------------------------------->
#
#
# Actual:  SAGY
# Predicted: SAGY
#
# Elapsed time=  0.264591867071419 s
# <------------------------------->
#
#
# Actual:  J87YQ
# Predicted: NP3D
#
# Elapsed time=  0.34559956424498706 s
# <------------------------------->
#
#
# Actual:  6GFZE
# Predicted: 6GFZE
#
# Elapsed time=  0.14324513091734914 s
# <------------------------------->
#
#
# Actual:  37HD
# Predicted: 37HD
#
# Elapsed time=  0.6053723444323189 s
# <------------------------------->
#
#
# Actual:  PMP2
# Predicted: 5G6G
#
# Elapsed time=  0.9800255481409677 s
# <------------------------------->
#
#
# Actual:  7EGQ
# Predicted: XH2X
#
# Elapsed time=  0.9907406786491859 s
# <------------------------------->
#
#
# Actual:  SZ5F
# Predicted: SZ5F
#
# Elapsed time=  0.6129065176067959 s
# <------------------------------->
#
#
# Actual:  82SRX
# Predicted: ACAA
#
# Elapsed time=  0.3601783443642137 s
# <------------------------------->
#
#
# Actual:  QBS3
# Predicted: QBS3
#
# Elapsed time=  0.3653952586358097 s
# <------------------------------->
#
#
# Actual:  KMX5
# Predicted: RPF7
#
# Elapsed time=  0.6111696228635339 s
# <------------------------------->
#
#
# Actual:  XS2E
# Predicted: XS2E
#
# Elapsed time=  0.29934044906524937 s
# <------------------------------->
#
#
# Actual:  WQYZ6
# Predicted: DZY1
#
# Elapsed time=  0.029822968913206016 s
# <------------------------------->
#
#
# Actual:  BJ1XP
# Predicted: HTPM
#
# Elapsed time=  0.3574064357767619 s
# <------------------------------->
#
#
# Actual:  94H5F
# Predicted: 94H5F
#
# Elapsed time=  0.6698271953748742 s
# <------------------------------->
#
#
# Actual:  3DJA3
# Predicted: PCPY
#
# Elapsed time=  0.6852869029815316 s
# <------------------------------->
#
#
# Actual:  7YP8
# Predicted: PBSZ
#
# Elapsed time=  0.22848201506683008 s
# <------------------------------->
#
#
# Actual:  1C2D
# Predicted: 1C2D
#
# Elapsed time=  0.4816226673516528 s
# <------------------------------->
#
#
# Actual:  6Y6S
# Predicted: BST6
#
# Elapsed time=  0.7186102707323607 s
# <------------------------------->
#
#
# Actual:  R8ECB
# Predicted: 976Y
#
# Elapsed time=  0.3101542221584084 s
# <------------------------------->
#
#
# Actual:  K65AE
# Predicted: 6F4U
#
# Elapsed time=  0.7570607224806346 s
# <------------------------------->
#
#
# Actual:  QH62
# Predicted: QH62
#
# Elapsed time=  0.2508662562194631 s
# <------------------------------->
#
#
# Actual:  B1XB6
# Predicted: TUW4
#
# Elapsed time=  0.8157531531782061 s
# <------------------------------->
#
#
# Actual:  GPECK
# Predicted: GPECK
#
# Elapsed time=  0.26073833183457185 s
# <------------------------------->
#
#
# Actual:  VG74C
# Predicted: DFWL
#
# Elapsed time=  0.9091838577448528 s
# <------------------------------->
#
#
# Actual:  LJZ9
# Predicted: MKJC
#
# Elapsed time=  0.40063890814711656 s
# <------------------------------->
#
#
# Actual:  9PST6
# Predicted: 9PST6
#
# Elapsed time=  0.17189321481367814 s
# <------------------------------->
#
#
# Actual:  L9G89
# Predicted: QLQ8
#
# Elapsed time=  0.03369330591601438 s
# <------------------------------->
#
#
# Actual:  9314
# Predicted: 9314
#
# Elapsed time=  0.49334890724850067 s
# <------------------------------->
#
#
# Actual:  QDQ5
# Predicted: QDQ5
#
# Elapsed time=  0.027489379601908115 s
# <------------------------------->
#
#
# Actual:  YLUA
# Predicted: 8KTP
#
# Elapsed time=  0.2449055378293732 s
# <------------------------------->
#
#
# Actual:  DJ5T
# Predicted: 9ULC
#
# Elapsed time=  0.4230775125616546 s
# <------------------------------->
#
#
# Actual:  687K9
# Predicted: EKCV
#
# Elapsed time=  0.34442076758482 s
# <------------------------------->
#
#
# Actual:  HU67D
# Predicted: KDNX
#
# Elapsed time=  0.6171065624762869 s
# <------------------------------->
#
#
# Actual:  8N25
# Predicted: 8N25
#
# Elapsed time=  0.771273167541544 s
# <------------------------------->
#
#
# Actual:  ATML
# Predicted: ATML
#
# Elapsed time=  0.1135222546924829 s
# <------------------------------->
#
#
# Actual:  WNDQV
# Predicted: WNDQV
#
# Elapsed time=  0.20585435963197374 s
# <------------------------------->
#
#
# Actual:  MUG3P
# Predicted: HFP4
#
# Elapsed time=  0.5199557212596027 s
# <------------------------------->
#
#
# Actual:  828B
# Predicted: 828B
#
# Elapsed time=  0.7129308604359728 s
# <------------------------------->
#
#
# Actual:  9VJ63
# Predicted: EF96
#
# Elapsed time=  0.5654974511604013 s
# <------------------------------->
#
#
# Actual:  N345N
# Predicted: N345N
#
# Elapsed time=  0.23066979443842617 s
# <------------------------------->
#
#
# Actual:  NSQLA
# Predicted: EYRL
#
# Elapsed time=  0.7844263716290795 s
# <------------------------------->
#
#
# Actual:  KCD34
# Predicted: KCD34
#
# Elapsed time=  0.7947587307007077 s
# <------------------------------->
#
#
# Actual:  BJ1XP
# Predicted: BJ1XP
#
# Elapsed time=  0.5380080471161072 s
# <------------------------------->
#
#
# Actual:  6JGW
# Predicted: HXA9
#
# Elapsed time=  0.05377484649531794 s
# <------------------------------->
#
#
# Actual:  EUJAL
# Predicted: EUJAL
#
# Elapsed time=  0.5049243898533019 s
# <------------------------------->
#
#
# Actual:  687K9
# Predicted: 687K9
#
# Elapsed time=  0.4072457068371754 s
# <------------------------------->
#
#
# Actual:  RBFQP
# Predicted: RBFQP
#
# Elapsed time=  0.6491703282040856 s
# <------------------------------->
#
#
# Actual:  7EQ4
# Predicted: 7EQ4
#
# Elapsed time=  0.7934242004640143 s
# <------------------------------->
#
#
# Actual:  JF6U
# Predicted: JF6U
#
# Elapsed time=  0.1309285023808735 s
# <------------------------------->
#
#
# Actual:  A69M
# Predicted: HW7W
#
# Elapsed time=  0.5201484479527665 s
# <------------------------------->
#
#
# Actual:  7EQ4
# Predicted: 7EQ4
#
# Elapsed time=  0.9622854934958699 s
# <------------------------------->
#
#
# Actual:  HHYYM
# Predicted: HPQ5
#
# Elapsed time=  0.2222831271255754 s
# <------------------------------->
#
#
# Actual:  MM5PL
# Predicted: MM5PL
#
# Elapsed time=  0.7939932497793355 s
# <------------------------------->
#
#
# Actual:  WM4YM
# Predicted: WM4YM
#
# Elapsed time=  0.5077701932843055 s
# <------------------------------->
#
#
# Actual:  XYY5X
# Predicted: XYY5X
#
# Elapsed time=  0.30165576120740145 s
# <------------------------------->
#
#
# Actual:  ULG7
# Predicted: ULG7
#
# Elapsed time=  0.8295891538707131 s
# <------------------------------->
#
#
# Actual:  3TND7
# Predicted: 3TND7
#
# Elapsed time=  0.38264852836253804 s
# <------------------------------->
#
#
# Actual:  DFGNM
# Predicted: DFGNM
#
# Elapsed time=  0.6643602575564868 s
# <------------------------------->
#
#
# Actual:  BH6H3
# Predicted: VU29
#
# Elapsed time=  0.332204778369929 s
# <------------------------------->
#
#
# Actual:  GYZB
# Predicted: GYZB
#
# Elapsed time=  0.8673465483717641 s
# <------------------------------->
#
#
# Actual:  MWAF
# Predicted: MWAF
#
# Elapsed time=  0.12463902678232985 s
# <------------------------------->
#
#
# Actual:  23LYD
# Predicted: QQ5J
#
# Elapsed time=  0.38513645158767795 s
# <------------------------------->
#
#
# Actual:  F8LN
# Predicted: FAXV
#
# Elapsed time=  0.5526631730984898 s
# <------------------------------->
#
#
# Actual:  6GCB
# Predicted: 41MQ
#
# Elapsed time=  0.6317529165775341 s
# <------------------------------->
#
#
# Actual:  VB6MF
# Predicted: 1U3V
#
# Elapsed time=  0.5854406743897949 s
# <------------------------------->
#
#
# Actual:  M428P
# Predicted: M428P
#
# Elapsed time=  0.23094211009327892 s
# <------------------------------->
#
#
# Actual:  Z6AG
# Predicted: Z6AG
#
# Elapsed time=  0.998055711728656 s
# <------------------------------->
#
#
# Actual:  AAXH
# Predicted: AAXH
#
# Elapsed time=  0.16628999879726747 s
# <------------------------------->
#
#
# Actual:  JCU1
# Predicted: JCU1
#
# Elapsed time=  0.3926768922702507 s
# <------------------------------->
#
#
# Actual:  S73RM
# Predicted: S73RM
#
# Elapsed time=  0.7678286577334816 s
# <------------------------------->
#
#
# Actual:  A69M
# Predicted: A69M
#
# Elapsed time=  0.8947938142903087 s
# <------------------------------->
#
#
# Actual:  VBFY
# Predicted: 1K7E
#
# Elapsed time=  0.2043578617985885 s
# <------------------------------->
#
#
# Actual:  RBFQP
# Predicted: RBFQP
#
# Elapsed time=  0.4355502965508038 s
# <------------------------------->
#
#
# Actual:  3NR4M
# Predicted: JZA2
#
# Elapsed time=  0.17064940843245235 s
# <------------------------------->
#
#
# Actual:  NRJ4
# Predicted: H2W4
#
# Elapsed time=  0.7768116398533514 s
# <------------------------------->
#
#
# Actual:  G8MUM
# Predicted: 6PE3
#
# Elapsed time=  0.12103714238659335 s
# <------------------------------->
#
#
# Actual:  7GPX2
# Predicted: 7GPX2
#
# Elapsed time=  0.7715237930022235 s
# <------------------------------->
#
#
# Actual:  77SV
# Predicted: KX7X
#
# Elapsed time=  0.1577629608241271 s
# <------------------------------->
#
#
# Actual:  F7PB
# Predicted: F7PB
#
# Elapsed time=  0.476048441546016 s
# <------------------------------->
#
#
# Actual:  1AUAK
# Predicted: 1AUAK
#
# Elapsed time=  0.8450745185663054 s
# <------------------------------->
#
#
# Actual:  7EN2R
# Predicted: YMVD
#
# Elapsed time=  0.3936841329813531 s
# <------------------------------->
#
#
# Actual:  DMFV
# Predicted: DMFV
#
# Elapsed time=  0.05581167221468408 s
# <------------------------------->
#
#
# Actual:  2ATV
# Predicted: 2ATV
#
# Elapsed time=  0.54588698362165 s
# <------------------------------->
#
#
# Actual:  PEMU2
# Predicted: JLPN
#
# Elapsed time=  0.01160154973083749 s
# <------------------------------->
#
#
# Actual:  1AUAK
# Predicted: 1AUAK
#
# Elapsed time=  0.5868465695676824 s
# <------------------------------->
#
#
# Actual:  83SFZ
# Predicted: 83SFZ
#
# Elapsed time=  0.9088949580288584 s
# <------------------------------->
#
#
# Actual:  4FR5K
# Predicted: ULSE
#
# Elapsed time=  0.5067493081255927 s
# <------------------------------->
#
#
# Actual:  GJC8H
# Predicted: YLKG
#
# Elapsed time=  0.34793002555108776 s
# <------------------------------->
#
#
# Actual:  M428P
# Predicted: M428P
#
# Elapsed time=  0.6350917083383687 s
# <------------------------------->
#
#
# Actual:  YMLU
# Predicted: 5PDQ
#
# Elapsed time=  0.43447217983183206 s
# <------------------------------->
#
#
# Actual:  MWAF
# Predicted: U8MF
#
# Elapsed time=  0.8828706743079956 s
# <------------------------------->
#
#
# Actual:  WVHUP
# Predicted: WVHUP
#
# Elapsed time=  0.2483455739335868 s
# <------------------------------->
#
#
# Actual:  BZJL
# Predicted: XGXQ
#
# Elapsed time=  0.4845993765807334 s
# <------------------------------->
#
#
# Actual:  FDSJ
# Predicted: FDSJ
#
# Elapsed time=  0.6817396492760919 s
# <------------------------------->
#
#
# Actual:  JHNG2
# Predicted: SSMS
#
# Elapsed time=  0.31001398998833196 s
# <------------------------------->
#
#
# Actual:  TNDK4
# Predicted: TNDK4
#
# Elapsed time=  0.4547131369725198 s
# <------------------------------->
#
#
# Actual:  KH6W
# Predicted: KH6W
#
# Elapsed time=  0.3535154472618397 s
# <------------------------------->
#
#
# Actual:  KGXLB
# Predicted: ZZWA
#
# Elapsed time=  0.16689101937752737 s
# <------------------------------->
#
#
# Actual:  GV18Q
# Predicted: GV18Q
#
# Elapsed time=  0.7824859455906948 s
# <------------------------------->
#
#
# Actual:  N345N
# Predicted: N345N
#
# Elapsed time=  0.4812287317211744 s
# <------------------------------->
#
#
# Actual:  Y6B9
# Predicted: Y6B9
#
# Elapsed time=  0.10388521810288631 s
# <------------------------------->
#
#
# Actual:  WNDQV
# Predicted: WNDQV
#
# Elapsed time=  0.9296334297528893 s
# <------------------------------->
#
#
# Actual:  LXNJ
# Predicted: P3F4
#
# Elapsed time=  0.41349343241065917 s
# <------------------------------->
#
#
# Actual:  Y6B9
# Predicted: 8FXV
#
# Elapsed time=  0.13152007556585543 s
# <------------------------------->
#
#
# Actual:  WBBW
# Predicted: ERHG
#
# Elapsed time=  0.7439060282754971 s
# <------------------------------->
#
#
# Actual:  7MW6W
# Predicted: SR6P
#
# Elapsed time=  0.9431648168343215 s
# <------------------------------->
#
#
# Actual:  TPS8H
# Predicted: TPS8H
#
# Elapsed time=  0.3256899306911849 s
# <------------------------------->
#
#
# Actual:  L3TND
# Predicted: UBB4
#
# Elapsed time=  0.7124061891222573 s
# <------------------------------->
#
#
# Actual:  YES2
# Predicted: YES2
#
# Elapsed time=  0.3471674373780389 s
# <------------------------------->
#
#
# Actual:  Z6FC
# Predicted: KC1H
#
# Elapsed time=  0.5601832836473616 s
# <------------------------------->
#
#
# Actual:  YV3Y3
# Predicted: YV3Y3
#
# Elapsed time=  0.6072069278998371 s
# <------------------------------->
#
#
# Actual:  L9G89
# Predicted: L9G89
#
# Elapsed time=  0.9768785512314445 s
# <------------------------------->
#
#
# Actual:  7HNAU
# Predicted: 7HNAU
#
# Elapsed time=  0.2838378276672233 s
# <------------------------------->
#
#
# Actual:  FJ5TR
# Predicted: 14XR
#
# Elapsed time=  0.09511770521352814 s
# <------------------------------->
#
#
# Actual:  9314
# Predicted: 9314
#
# Elapsed time=  0.4119321579330243 s
# <------------------------------->
#
#
# Actual:  X1MX
# Predicted: V4BQ
#
# Elapsed time=  0.31800693231086086 s
# <------------------------------->
#
#
# Actual:  R9LD
# Predicted: UJGD
#
# Elapsed time=  0.13231340767583433 s
# <------------------------------->
#
#
# Actual:  6K4S
# Predicted: 6DYN
#
# Elapsed time=  0.2857971976999395 s
# <------------------------------->
#
#
# Actual:  4YTU1
# Predicted: 4YTU1
#
# Elapsed time=  0.8170845573521615 s
# <------------------------------->
#
#
# Actual:  4HE2
# Predicted: 4HE2
#
# Elapsed time=  0.7656653625125643 s
# <------------------------------->
#
#
# Actual:  4YTU1
# Predicted: 95EP
#
# Elapsed time=  0.8579761011034762 s
# <------------------------------->
#
#
# Actual:  KEX4
# Predicted: KEX4
#
# Elapsed time=  0.09500411575092893 s
# <------------------------------->
#
#
# Actual:  L8WBE
# Predicted: L8WBE
#
# Elapsed time=  0.0798881661090205 s
# <------------------------------->
#
#
# Actual:  Z9CM
# Predicted: Y77P
#
# Elapsed time=  0.9090254982578387 s
# <------------------------------->
#
#
# Actual:  12QM
# Predicted: 12QM
#
# Elapsed time=  0.8573727525478291 s
# <------------------------------->
#
#
# Actual:  DJBB
# Predicted: N5UC
#
# Elapsed time=  0.696262923583768 s
# <------------------------------->
#
#
# Actual:  1U17Q
# Predicted: X1YL
#
# Elapsed time=  0.8863560972645954 s
# <------------------------------->
#
#
# Actual:  KMMY
# Predicted: 4D5L
#
# Elapsed time=  0.6062076068657479 s
# <------------------------------->
#
#
# Actual:  L8WBE
# Predicted: PXKY
#
# Elapsed time=  0.889470540866175 s
# <------------------------------->
#
#
# Actual:  Q7WJY
# Predicted: Q7WJY
#
# Elapsed time=  0.501953670415221 s
# <------------------------------->
#
#
# Actual:  KEFN
# Predicted: KEFN
#
# Elapsed time=  0.742607409703017 s
# <------------------------------->
#
#
# Actual:  6L837
# Predicted: 6L837
#
# Elapsed time=  0.8864377143207359 s
# <------------------------------->
#
#
# Actual:  ZJS3
# Predicted: ZJS3
#
# Elapsed time=  0.07148439221214153 s
# <------------------------------->
#
#
# Actual:  66GQK
# Predicted: C761
#
# Elapsed time=  0.39069209246177683 s
# <------------------------------->
#
#
# Actual:  9D7E
# Predicted: 9D7E
#
# Elapsed time=  0.8074223497918592 s
# <------------------------------->
#
#
# Actual:  NQCC3
# Predicted: AAPG
#
# Elapsed time=  0.23513073911098903 s
# <------------------------------->
#
#
# Actual:  4E8QZ
# Predicted: RK76
#
# Elapsed time=  0.6090645019999349 s
# <------------------------------->
#
#
# Actual:  8M69
# Predicted: 8M69
#
# Elapsed time=  0.7881683359128792 s
# <------------------------------->
#
#
# Actual:  MF7DA
# Predicted: FM8W
#
# Elapsed time=  0.14062856270197166 s
# <------------------------------->
#
#
# Actual:  GV18Q
# Predicted: GV18Q
#
# Elapsed time=  0.039888393157550106 s
# <------------------------------->
#
#
# Actual:  KSHL
# Predicted: KSHL
#
# Elapsed time=  0.6048681385856 s
# <------------------------------->
#
#
# Actual:  P3NJM
# Predicted: RWUJ
#
# Elapsed time=  0.43025282229504136 s
# <------------------------------->
#
#
# Actual:  4WG4S
# Predicted: GXB9
#
# Elapsed time=  0.10676129512082377 s
# <------------------------------->
#
#
# Actual:  T1MNT
# Predicted: GXDY
#
# Elapsed time=  0.3702297013882878 s
# <------------------------------->
#
#
# Actual:  6JGW
# Predicted: 6JGW
#
# Elapsed time=  0.833684338832555 s
# <------------------------------->
#
#
# Actual:  X6SH
# Predicted: J5YL
#
# Elapsed time=  0.6178831421157438 s
# <------------------------------->
#
#
# Actual:  94H5F
# Predicted: 94H5F
#
# Elapsed time=  0.014026925153085124 s
# <------------------------------->
#
#
# Actual:  YXFG
# Predicted: YXFG
#
# Elapsed time=  0.297637921140662 s
# <------------------------------->
#
#
# Actual:  26UUW
# Predicted: 26UUW
#
# Elapsed time=  0.6579117346053626 s
# <------------------------------->
#
#
# Actual:  PGBZP
# Predicted: QZ5J
#
# Elapsed time=  0.2175037069208956 s
# <------------------------------->
#
#
# Actual:  KH6W
# Predicted: KH6W
#
# Elapsed time=  0.4259750319387279 s
# <------------------------------->
#
#
# Actual:  SAGY
# Predicted: SAGY
#
# Elapsed time=  0.8990826633850918 s
# <------------------------------->
#
#
# Actual:  828B
# Predicted: 828B
#
# Elapsed time=  0.4357161997189679 s
# <------------------------------->
#
#
# Actual:  M1QN
# Predicted: R9GR
#
# Elapsed time=  0.3071427551509335 s
# <------------------------------->
#
#
# Actual:  VBFY
# Predicted: VBFY
#
# Elapsed time=  0.12576532670524687 s
# <------------------------------->
#
#
# Actual:  ZJX2L
# Predicted: 8NX4
#
# Elapsed time=  0.675236239588998 s
# <------------------------------->
#
#
# Actual:  PEMU2
# Predicted: PEMU2
#
# Elapsed time=  0.7241122913844805 s
# <------------------------------->
#
#
# Actual:  S46B
# Predicted: VU36
#
# Elapsed time=  0.7084862853229948 s
# <------------------------------->
#
#
# Actual:  Q7WP
# Predicted: N288
#
# Elapsed time=  0.34947634533534755 s
# <------------------------------->
#
#
# Actual:  PXL61
# Predicted: 4Y8K
#
# Elapsed time=  0.5522437594842837 s
# <------------------------------->
#
#
# Actual:  PXPS
# Predicted: PXPS
#
# Elapsed time=  0.8826623721668847 s
# <------------------------------->
#
#
# Actual:  VX1M6
# Predicted: 9CNG
#
# Elapsed time=  0.7285005668031695 s
# <------------------------------->
#
#
# Actual:  DFGNM
# Predicted: LXXQ
#
# Elapsed time=  0.06349815586754826 s
# <------------------------------->
#
#
# Actual:  VF71
# Predicted: SHWX
#
# Elapsed time=  0.5269768041465887 s
# <------------------------------->
#
#
# Actual:  WHGHF
# Predicted: 2QKD
#
# Elapsed time=  0.9988982815128415 s
# <------------------------------->
# Total number of CAPTCHAS broken:  214
# Total number of CAPTCHAS attempted:  398
# Total time taken=  125.24161444845721 s
# Accuracy=  53.768844221105525
