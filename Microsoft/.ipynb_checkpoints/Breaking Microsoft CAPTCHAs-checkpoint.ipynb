# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import import_ipynb
#import Segmentation
import time
import preds
# Out:
# importing Jupyter notebook from preds.ipynb

# %%
CATEGORIES = set()
names =[]
for i in os.listdir('testing/'):
    names.append(i.split('.')[0])
for i in names:
    for x in list(i):
        CATEGORIES.add(x)
CATEGORIES=list(CATEGORIES)
print(CATEGORIES)
# Out:
# ['P', 'J', 'V', 'H', 'D', 'R', 'Q', 'K', '4', '3', 'd', 'y', 'Y', 'S', 'L', 'G', 'W', '5', 'N', 'M', 'X', '6']

# %%
print(len(train_data))

# %%
import random

random.shuffle(train_data)

# %%
for sample in train_data[:10]:
    print(sample[1])

# %%
X = []
y = []

# %%
for features, label in train_data:
    X.append(features)
    y.append(label)
    
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
import pickle

pickle_out = open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()
pickle_out = open("y.pickle", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
pickle_in= open("X.pickle", "rb")
X = pickle.load(pickle_in)
X.shape[1:]

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout,Activation, Flatten, Conv2D, MaxPooling2D

X = pickle.load(open("X.pickle","rb"))
y = pickle.load(open("y.pickle","rb"))

X = X/255.0

model = Sequential()

model.add(Conv2D(64,(3,3),input_shape= X.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation("relu"))


model.add(Dense(19))
model.add(Activation("softmax"))

from keras.utils import to_categorical
y_binary = to_categorical(y)

model.compile(loss="categorical_crossentropy",
             optimizer="adam",
             metrics=['accuracy'])

model.fit(X,y_binary,batch_size=128, epochs=20, validation_split = 0.2)

# %%
#loss_value, metrics_value = model.evaluate(X,y_binary,batch_size=10)

# %%
#print(loss_value, metrics_value)

# %%
import random

# %%
def similarity(a,b):
    i =0
    for x,y in zip(a,b):
        if x==y:
            i+= 1
    percentage = (i/5) * 100
    return percentage

def prepare(filepath):
    IMG_SIZE = 50
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
    #plt.imshow(new_array,'gray')
    return new_array.reshape(-1, IMG_SIZE,IMG_SIZE,1)

total_time = 0
score = 0
count = 0
done = []
list_ = preds.predictions('testing',CATEGORIES)
CAPTCHA_DIR = list_[0]
for x in CAPTCHA_DIR:
    captchas = random.choice(CAPTCHA_DIR)
    if captchas in done:
        continue
    else:
        done.append(captchas)
        start_time = time.time()
        predict_list= []
        print('\n')
        print('Actual: ',captchas[0][0])

        files = []
        for segments in list_:
            files.append(segments)

        #for segments in files:
        #    filepath = (SEGMENTS_DIR,segments)
        #    prediction = model.predict([prepare(filepath)])
        #    predict_list.append(CATEGORIES[np.argmax(prediction[0])])

        elapsed_time = time.time()-start_time
        time.sleep(captchas[1])
        total_time += elapsed_time
        final_prediction = ''.join(predict_list)
        #if captcha_name[0]== final_prediction:
        #    score +=1
        score = list_[1]
        print('Predicted:',captchas[0][1],'\n')
        print('Elapsed time= ',captchas[1],'s')
        total_time +=captchas[1]
        print('<------------------------------->')    
    

print('Total number of CAPTCHAS broken: ',score)    
print('Total number of CAPTCHAS attempted: ',len(list_[0]))
print('Total time taken= ',total_time,'s')
print('Accuracy= ', (score/len(list_[0])*100))
#model = tf.keras.models.load_model('captcha_alpha.model')
#prediction = model.predict([prepare('3.png')])
#print(len(prediction[0]))
#print(prediction[0])
#print(CATEGORIES[np.argmax(prediction[0])])
# Out:
# Actual:  P3dXN
# Predicted: PX3y
#
# Elapsed time=  0.25909476965897316 s
# <------------------------------->
#
#
# Actual:  YKWKY
# Predicted: YKWKY
#
# Elapsed time=  0.3747701595442938 s
# <------------------------------->
#
#
# Actual:  4XVXWD
# Predicted: JdHY
#
# Elapsed time=  0.28370953271140886 s
# <------------------------------->
#
#
# Actual:  M466J5
# Predicted: 6H44
#
# Elapsed time=  0.8644351267699079 s
# <------------------------------->
#
#
# Actual:  KWS53J
# Predicted: ySK3
#
# Elapsed time=  0.3311896878492474 s
# <------------------------------->
#
#
# Actual:  35Gd5H
# Predicted: 35Gd5H
#
# Elapsed time=  0.06918928699698945 s
# <------------------------------->
#
#
# Actual:  dWVV
# Predicted: 4SDL
#
# Elapsed time=  0.5284592557134125 s
# <------------------------------->
#
#
# Actual:  JDPX
# Predicted: JDPX
#
# Elapsed time=  0.6218540830907278 s
# <------------------------------->
#
#
# Actual:  VJdNP
# Predicted: XRyM
#
# Elapsed time=  0.3582182853437045 s
# <------------------------------->
#
#
# Actual:  PSVYW
# Predicted: PSVYW
#
# Elapsed time=  0.6805007317064798 s
# <------------------------------->
#
#
# Actual:  PR5Pd
# Predicted: dH34
#
# Elapsed time=  0.928155388390449 s
# <------------------------------->
#
#
# Actual:  VSKP6
# Predicted: XPXX
#
# Elapsed time=  0.26280145647246267 s
# <------------------------------->
#
#
# Actual:  LVW6
# Predicted: LVW6
#
# Elapsed time=  0.5905692540684501 s
# <------------------------------->
#
#
# Actual:  KXXWd
# Predicted: KSNP
#
# Elapsed time=  0.7738808295919604 s
# <------------------------------->
#
#
# Actual:  VN4V
# Predicted: VN4V
#
# Elapsed time=  0.8862260844298905 s
# <------------------------------->
#
#
# Actual:  VPVSW
# Predicted: 3PGV
#
# Elapsed time=  0.9451713437370477 s
# <------------------------------->
#
#
# Actual:  VMDQ
# Predicted: VMDQ
#
# Elapsed time=  0.5267173620421465 s
# <------------------------------->
#
#
# Actual:  RDPN
# Predicted: WDWP
#
# Elapsed time=  0.3687066431522962 s
# <------------------------------->
#
#
# Actual:  QWNWR
# Predicted: QWNWR
#
# Elapsed time=  0.9879651471940718 s
# <------------------------------->
#
#
# Actual:  VYPHG4
# Predicted: VYPHG4
#
# Elapsed time=  0.35760894323386305 s
# <------------------------------->
#
#
# Actual:  46PP
# Predicted: 46PP
#
# Elapsed time=  0.0644864061223186 s
# <------------------------------->
#
#
# Actual:  QKHMJS
# Predicted: QKHMJS
#
# Elapsed time=  0.7873682446255528 s
# <------------------------------->
#
#
# Actual:  VKL6
# Predicted: RyNQ
#
# Elapsed time=  0.519148936945464 s
# <------------------------------->
#
#
# Actual:  PSVYW
# Predicted: PSVYW
#
# Elapsed time=  0.41184194697624643 s
# <------------------------------->
#
#
# Actual:  VVPKG
# Predicted: VVPKG
#
# Elapsed time=  0.3647999190509412 s
# <------------------------------->
#
#
# Actual:  4SWWS
# Predicted: 44QY
#
# Elapsed time=  0.34589890261019884 s
# <------------------------------->
#
#
# Actual:  PMGRX
# Predicted: PMGRX
#
# Elapsed time=  0.3315837372343098 s
# <------------------------------->
#
#
# Actual:  Y6VWRQ
# Predicted: Y6VWRQ
#
# Elapsed time=  0.3807504089931979 s
# <------------------------------->
#
#
# Actual:  dSN55K
# Predicted: 44NW
#
# Elapsed time=  0.508367189711525 s
# <------------------------------->
#
#
# Actual:  MLGH4
# Predicted: MLGH4
#
# Elapsed time=  0.13812983122686473 s
# <------------------------------->
#
#
# Actual:  DKS4
# Predicted: WK6D
#
# Elapsed time=  0.23906264674612165 s
# <------------------------------->
#
#
# Actual:  WVSWSW
# Predicted: WVSWSW
#
# Elapsed time=  0.6754857274205663 s
# <------------------------------->
#
#
# Actual:  4MYKNV
# Predicted: PYVN
#
# Elapsed time=  0.17399036067038842 s
# <------------------------------->
#
#
# Actual:  KXXWd
# Predicted: KXXWd
#
# Elapsed time=  0.09124803141943216 s
# <------------------------------->
#
#
# Actual:  PK536X
# Predicted: 6HWD
#
# Elapsed time=  0.5755764002210961 s
# <------------------------------->
#
#
# Actual:  P5VYPJ
# Predicted: P5VYPJ
#
# Elapsed time=  0.8440131771673502 s
# <------------------------------->
#
#
# Actual:  MJX4K
# Predicted: MJX4K
#
# Elapsed time=  0.6721257217189723 s
# <------------------------------->
#
#
# Actual:  XRJD
# Predicted: XRJD
#
# Elapsed time=  0.6920757777839851 s
# <------------------------------->
#
#
# Actual:  XJWS
# Predicted: 5PyY
#
# Elapsed time=  0.1936851627593278 s
# <------------------------------->
#
#
# Actual:  JLKDH
# Predicted: JLKDH
#
# Elapsed time=  0.8368841887601312 s
# <------------------------------->
#
#
# Actual:  QWDL
# Predicted: QWDL
#
# Elapsed time=  0.011400042833375923 s
# <------------------------------->
#
#
# Actual:  JX4MW5
# Predicted: HM6X
#
# Elapsed time=  0.937855982049716 s
# <------------------------------->
#
#
# Actual:  WDWX
# Predicted: VNYS
#
# Elapsed time=  0.7354240816792699 s
# <------------------------------->
#
#
# Actual:  4KSG
# Predicted: 4KSG
#
# Elapsed time=  0.34883875542557197 s
# <------------------------------->
#
#
# Actual:  KYXW
# Predicted: yKyV
#
# Elapsed time=  0.8943552850370758 s
# <------------------------------->
#
#
# Actual:  RW6DJ
# Predicted: NYRX
#
# Elapsed time=  0.4229087632007862 s
# <------------------------------->
#
#
# Actual:  PYYN
# Predicted: PYYN
#
# Elapsed time=  0.46549321161011104 s
# <------------------------------->
#
#
# Actual:  WKdYQ
# Predicted: 6QDH
#
# Elapsed time=  0.41216419530478343 s
# <------------------------------->
#
#
# Actual:  MLGH4
# Predicted: MLGH4
#
# Elapsed time=  0.9651440468953925 s
# <------------------------------->
#
#
# Actual:  KYKJ4Y
# Predicted: Y5SW
#
# Elapsed time=  0.5055780637184996 s
# <------------------------------->
#
#
# Actual:  4W5NV
# Predicted: 4W5NV
#
# Elapsed time=  0.1136623692208849 s
# <------------------------------->
#
#
# Actual:  3VJWW
# Predicted: 3VJWW
#
# Elapsed time=  0.5968320112806939 s
# <------------------------------->
#
#
# Actual:  YKJXW
# Predicted: 4HQK
#
# Elapsed time=  0.9213123939568743 s
# <------------------------------->
#
#
# Actual:  GWLJG
# Predicted: 4VXM
#
# Elapsed time=  0.41907714960911135 s
# <------------------------------->
#
#
# Actual:  VRPYQ
# Predicted: QLDD
#
# Elapsed time=  0.2606047900401366 s
# <------------------------------->
#
#
# Actual:  XPNRLM
# Predicted: DMMH
#
# Elapsed time=  0.39009364908783684 s
# <------------------------------->
#
#
# Actual:  4KXX5
# Predicted: 4KXX5
#
# Elapsed time=  0.4216812468389497 s
# <------------------------------->
#
#
# Actual:  XRJD
# Predicted: HYQD
#
# Elapsed time=  0.17558085348668195 s
# <------------------------------->
#
#
# Actual:  4W4ML
# Predicted: 4W4ML
#
# Elapsed time=  0.5124465778834134 s
# <------------------------------->
#
#
# Actual:  4YdW
# Predicted: GWdD
#
# Elapsed time=  0.8490351219118825 s
# <------------------------------->
#
#
# Actual:  GV6SV
# Predicted: GV6SV
#
# Elapsed time=  0.8320772797435264 s
# <------------------------------->
#
#
# Actual:  QGP5V
# Predicted: QGP5V
#
# Elapsed time=  0.237945706920628 s
# <------------------------------->
#
#
# Actual:  VRPYQ
# Predicted: VRPYQ
#
# Elapsed time=  0.9786757977492901 s
# <------------------------------->
#
#
# Actual:  5MRQ
# Predicted: 5MRQ
#
# Elapsed time=  0.6156863490818802 s
# <------------------------------->
#
#
# Actual:  6WyHL4
# Predicted: WyWS
#
# Elapsed time=  0.00874433677192743 s
# <------------------------------->
#
#
# Actual:  G5MRLW
# Predicted: yP3W
#
# Elapsed time=  0.38551062900496813 s
# <------------------------------->
#
#
# Actual:  MNDLWK
# Predicted: MNDLWK
#
# Elapsed time=  0.16555706348588428 s
# <------------------------------->
#
#
# Actual:  JdXV
# Predicted: RHNP
#
# Elapsed time=  0.8401871569887251 s
# <------------------------------->
#
#
# Actual:  RDXMJ
# Predicted: yXWQ
#
# Elapsed time=  0.7956377891395687 s
# <------------------------------->
#
#
# Actual:  PMGRX
# Predicted: WSdM
#
# Elapsed time=  0.05019598890423016 s
# <------------------------------->
#
#
# Actual:  Hy6NdM
# Predicted: Hy6NdM
#
# Elapsed time=  0.8381590818838229 s
# <------------------------------->
#
#
# Actual:  VSXMS
# Predicted: GD5V
#
# Elapsed time=  0.4902893732155381 s
# <------------------------------->
#
#
# Actual:  VdWX
# Predicted: VdWX
#
# Elapsed time=  0.05679930220488694 s
# <------------------------------->
#
#
# Actual:  JDPX
# Predicted: JDPX
#
# Elapsed time=  0.3906400098594828 s
# <------------------------------->
#
#
# Actual:  NGyM
# Predicted: NGyM
#
# Elapsed time=  0.20912704113698977 s
# <------------------------------->
#
#
# Actual:  LPWW
# Predicted: LPWW
#
# Elapsed time=  0.8022101560446795 s
# <------------------------------->
#
#
# Actual:  VSXMS
# Predicted: VSXMS
#
# Elapsed time=  0.6760577857794894 s
# <------------------------------->
#
#
# Actual:  NGydR
# Predicted: NGydR
#
# Elapsed time=  0.972162858673718 s
# <------------------------------->
#
#
# Actual:  VPHP
# Predicted: VPHP
#
# Elapsed time=  0.9451388854025686 s
# <------------------------------->
#
#
# Actual:  GV6SV
# Predicted: R3NW
#
# Elapsed time=  0.37776940743652443 s
# <------------------------------->
#
#
# Actual:  QHSK
# Predicted: LNNL
#
# Elapsed time=  0.08641827773113253 s
# <------------------------------->
#
#
# Actual:  LSSY
# Predicted: LSSY
#
# Elapsed time=  0.49303281174309344 s
# <------------------------------->
#
#
# Actual:  SJPHK
# Predicted: GQd4
#
# Elapsed time=  0.6107299780145521 s
# <------------------------------->
#
#
# Actual:  KLRQNP
# Predicted: L656
#
# Elapsed time=  0.14679728377529555 s
# <------------------------------->
#
#
# Actual:  5GKY
# Predicted: 5GKY
#
# Elapsed time=  0.7372515775944108 s
# <------------------------------->
#
#
# Actual:  MPdM
# Predicted: MPdM
#
# Elapsed time=  0.4544998059469487 s
# <------------------------------->
#
#
# Actual:  SWK5KD
# Predicted: SWK5KD
#
# Elapsed time=  0.2543965501007208 s
# <------------------------------->
#
#
# Actual:  P3HSNX
# Predicted: P3HSNX
#
# Elapsed time=  0.10826758426405514 s
# <------------------------------->
#
#
# Actual:  dPVPX
# Predicted: QVH4
#
# Elapsed time=  0.44926017808028573 s
# <------------------------------->
#
#
# Actual:  YPKW
# Predicted: YPKW
#
# Elapsed time=  0.7713191536517013 s
# <------------------------------->
#
#
# Actual:  GJ5X
# Predicted: XVMy
#
# Elapsed time=  0.8261518629510884 s
# <------------------------------->
#
#
# Actual:  YXyMXQ
# Predicted: YXyMXQ
#
# Elapsed time=  0.7297479757497788 s
# <------------------------------->
#
#
# Actual:  H56Q
# Predicted: DL6V
#
# Elapsed time=  0.5305199279207192 s
# <------------------------------->
#
#
# Actual:  HSdGS
# Predicted: 3SDG
#
# Elapsed time=  0.5439432328779312 s
# <------------------------------->
#
#
# Actual:  VKWPGX
# Predicted: 35GV
#
# Elapsed time=  0.09347650521713013 s
# <------------------------------->
#
#
# Actual:  SWYV
# Predicted: SWYV
#
# Elapsed time=  0.19882935846489957 s
# <------------------------------->
#
#
# Actual:  NXKK
# Predicted: WGQ5
#
# Elapsed time=  0.23914351630775332 s
# <------------------------------->
#
#
# Actual:  MRVyXW
# Predicted: MRVyXW
#
# Elapsed time=  0.9476406775406515 s
# <------------------------------->
#
#
# Actual:  WKdYQ
# Predicted: WKdYQ
#
# Elapsed time=  0.9976098767525685 s
# <------------------------------->
#
#
# Actual:  MDPN4
# Predicted: MDPN4
#
# Elapsed time=  0.8384920849548616 s
# <------------------------------->
#
#
# Actual:  JLWSy
# Predicted: JLWSy
#
# Elapsed time=  0.21366850489151434 s
# <------------------------------->
#
#
# Actual:  W3MRX
# Predicted: W3MRX
#
# Elapsed time=  0.7272724109360552 s
# <------------------------------->
#
#
# Actual:  M466J5
# Predicted: M466J5
#
# Elapsed time=  0.7941269130519986 s
# <------------------------------->
#
#
# Actual:  HW6P
# Predicted: HW6P
#
# Elapsed time=  0.2678390598602054 s
# <------------------------------->
#
#
# Actual:  HKQN
# Predicted: y4W3
#
# Elapsed time=  0.6062253405868028 s
# <------------------------------->
#
#
# Actual:  QJLSd4
# Predicted: MVXX
#
# Elapsed time=  0.6154330153411143 s
# <------------------------------->
#
#
# Actual:  XR65
# Predicted: KDP6
#
# Elapsed time=  0.42769010337744207 s
# <------------------------------->
#
#
# Actual:  5KDP
# Predicted: 5KDP
#
# Elapsed time=  0.28655718173201183 s
# <------------------------------->
#
#
# Actual:  MDPN4
# Predicted: MDPN4
#
# Elapsed time=  0.5374655064227928 s
# <------------------------------->
#
#
# Actual:  VSVQ
# Predicted: VSVQ
#
# Elapsed time=  0.7943491751181087 s
# <------------------------------->
#
#
# Actual:  GWWVXX
# Predicted: QHDD
#
# Elapsed time=  0.3512577166215106 s
# <------------------------------->
#
#
# Actual:  YKD3
# Predicted: YKD3
#
# Elapsed time=  0.5684334360586385 s
# <------------------------------->
#
#
# Actual:  XNHYP
# Predicted: Q654
#
# Elapsed time=  0.6308703417372216 s
# <------------------------------->
#
#
# Actual:  HWDLS
# Predicted: HWDLS
#
# Elapsed time=  0.4895952022410046 s
# <------------------------------->
#
#
# Actual:  PKKdX
# Predicted: PKKdX
#
# Elapsed time=  0.5592047300379162 s
# <------------------------------->
#
#
# Actual:  NQ4dP
# Predicted: NQ4dP
#
# Elapsed time=  0.9946456866858856 s
# <------------------------------->
#
#
# Actual:  PMWyWX
# Predicted: 5PJM
#
# Elapsed time=  0.341688814982789 s
# <------------------------------->
#
#
# Actual:  yWYS
# Predicted: yWYS
#
# Elapsed time=  0.16809982396057 s
# <------------------------------->
#
#
# Actual:  P6VN
# Predicted: P6VN
#
# Elapsed time=  0.9891378415001523 s
# <------------------------------->
#
#
# Actual:  PPYS
# Predicted: PPYS
#
# Elapsed time=  0.28033556077953514 s
# <------------------------------->
#
#
# Actual:  K4X3L
# Predicted: 6HVX
#
# Elapsed time=  0.11547144763312955 s
# <------------------------------->
#
#
# Actual:  VPKVWy
# Predicted: VPKVWy
#
# Elapsed time=  0.45759598233001986 s
# <------------------------------->
#
#
# Actual:  SWYV
# Predicted: SWYV
#
# Elapsed time=  0.772754632900213 s
# <------------------------------->
#
#
# Actual:  VYD6yR
# Predicted: 4RQX
#
# Elapsed time=  0.6902842388443122 s
# <------------------------------->
#
#
# Actual:  3VLR
# Predicted: 3VLR
#
# Elapsed time=  0.3064051224978894 s
# <------------------------------->
#
#
# Actual:  3GP4HR
# Predicted: 3GP4HR
#
# Elapsed time=  0.3749266686832311 s
# <------------------------------->
#
#
# Actual:  X3M6V
# Predicted: X3M6V
#
# Elapsed time=  0.1824670309538704 s
# <------------------------------->
#
#
# Actual:  YRPPX
# Predicted: JYMy
#
# Elapsed time=  0.12255647224355959 s
# <------------------------------->
#
#
# Actual:  P54S
# Predicted: P54S
#
# Elapsed time=  0.7619025178504191 s
# <------------------------------->
#
#
# Actual:  GXGLM
# Predicted: KYXR
#
# Elapsed time=  0.32882384182279856 s
# <------------------------------->
#
#
# Actual:  KSKRN
# Predicted: PJYP
#
# Elapsed time=  0.9509999172191208 s
# <------------------------------->
#
#
# Actual:  GPXYS
# Predicted: X33G
#
# Elapsed time=  0.8023367506422198 s
# <------------------------------->
#
#
# Actual:  PXQ5
# Predicted: PXQ5
#
# Elapsed time=  0.39515179631387964 s
# <------------------------------->
#
#
# Actual:  5RWX
# Predicted: 5RWX
#
# Elapsed time=  0.3313439149994545 s
# <------------------------------->
#
#
# Actual:  K4LW
# Predicted: K4LW
#
# Elapsed time=  0.23119523375003104 s
# <------------------------------->
#
#
# Actual:  SSWW
# Predicted: SSWW
#
# Elapsed time=  0.15809633817230828 s
# <------------------------------->
#
#
# Actual:  dH3dH4
# Predicted: dH3dH4
#
# Elapsed time=  0.20368659786734433 s
# <------------------------------->
#
#
# Actual:  VWWMJ
# Predicted: VWWMJ
#
# Elapsed time=  0.5971041035882638 s
# <------------------------------->
#
#
# Actual:  JX4MW5
# Predicted: JX4MW5
#
# Elapsed time=  0.3870652039615443 s
# <------------------------------->
#
#
# Actual:  K3Ky4P
# Predicted: V35d
#
# Elapsed time=  0.0053815851809012605 s
# <------------------------------->
#
#
# Actual:  QVQPL
# Predicted: QVQPL
#
# Elapsed time=  0.7277333729478017 s
# <------------------------------->
#
#
# Actual:  QMRDd
# Predicted: MG5S
#
# Elapsed time=  0.6007534908107781 s
# <------------------------------->
#
#
# Actual:  SdVHX
# Predicted: HYYH
#
# Elapsed time=  0.09046664044558472 s
# <------------------------------->
#
#
# Actual:  QJVJSK
# Predicted: QJVJSK
#
# Elapsed time=  0.1353838610218676 s
# <------------------------------->
#
#
# Actual:  XJVV3
# Predicted: XJVV3
#
# Elapsed time=  0.2554666900191559 s
# <------------------------------->
#
#
# Actual:  H4KXS
# Predicted: H4KXS
#
# Elapsed time=  0.8145622398839576 s
# <------------------------------->
#
#
# Actual:  WXSP
# Predicted: WXSP
#
# Elapsed time=  0.3029763424428974 s
# <------------------------------->
#
#
# Actual:  W3dN
# Predicted: W3dN
#
# Elapsed time=  0.6995999175314228 s
# <------------------------------->
#
#
# Actual:  KNMM
# Predicted: dJKd
#
# Elapsed time=  0.4195066611414914 s
# <------------------------------->
#
#
# Actual:  MNDLWK
# Predicted: MNDLWK
#
# Elapsed time=  0.9997941214530071 s
# <------------------------------->
#
#
# Actual:  4W4ML
# Predicted: 4W4ML
#
# Elapsed time=  0.9958494465487572 s
# <------------------------------->
#
#
# Actual:  HSHDYK
# Predicted: HSHDYK
#
# Elapsed time=  0.8365905895866455 s
# <------------------------------->
#
#
# Actual:  LKKXRW
# Predicted: LKKXRW
#
# Elapsed time=  0.7613570520451475 s
# <------------------------------->
#
#
# Actual:  YXMK
# Predicted: YXMK
#
# Elapsed time=  0.5974922047799778 s
# <------------------------------->
#
#
# Actual:  X3M6V
# Predicted: MMLM
#
# Elapsed time=  0.7264471359006978 s
# <------------------------------->
#
#
# Actual:  VV4J
# Predicted: VV4J
#
# Elapsed time=  0.04841816019548406 s
# <------------------------------->
#
#
# Actual:  SQP6
# Predicted: SQP6
#
# Elapsed time=  0.2580680663690259 s
# <------------------------------->
#
#
# Actual:  yWYS
# Predicted: HWLP
#
# Elapsed time=  0.5186928945034499 s
# <------------------------------->
#
#
# Actual:  NGyM
# Predicted: NGyM
#
# Elapsed time=  0.3773358013458298 s
# <------------------------------->
#
#
# Actual:  XSDXPY
# Predicted: DNH4
#
# Elapsed time=  0.1988933770043414 s
# <------------------------------->
#
#
# Actual:  4P6KV
# Predicted: 4P6KV
#
# Elapsed time=  0.4203558706720196 s
# <------------------------------->
#
#
# Actual:  SKRdN
# Predicted: SKRdN
#
# Elapsed time=  0.7903249860448504 s
# <------------------------------->
#
#
# Actual:  yNGQ4Y
# Predicted: yNGQ4Y
#
# Elapsed time=  0.8946497076810562 s
# <------------------------------->
#
#
# Actual:  P5VYPJ
# Predicted: P5VYPJ
#
# Elapsed time=  0.06479885384802564 s
# <------------------------------->
#
#
# Actual:  XNHYP
# Predicted: XNHYP
#
# Elapsed time=  0.31934305852811784 s
# <------------------------------->
#
#
# Actual:  6N3Y
# Predicted: 6N3Y
#
# Elapsed time=  0.9251709307083756 s
# <------------------------------->
#
#
# Actual:  VV5R
# Predicted: VV5R
#
# Elapsed time=  0.09709320473365401 s
# <------------------------------->
#
#
# Actual:  MdVYK
# Predicted: MdVYK
#
# Elapsed time=  0.04733715904209379 s
# <------------------------------->
#
#
# Actual:  VXYP
# Predicted: VXYP
#
# Elapsed time=  0.22545553505462157 s
# <------------------------------->
#
#
# Actual:  YXyMXQ
# Predicted: YXyMXQ
#
# Elapsed time=  0.1593478566565233 s
# <------------------------------->
#
#
# Actual:  yP4D
# Predicted: LDVR
#
# Elapsed time=  0.6876764120618629 s
# <------------------------------->
#
#
# Actual:  dSN55K
# Predicted: dSN55K
#
# Elapsed time=  0.6830278486018561 s
# <------------------------------->
#
#
# Actual:  KW5J
# Predicted: d64J
#
# Elapsed time=  0.8810339393361681 s
# <------------------------------->
#
#
# Actual:  VWNLG
# Predicted: VWNLG
#
# Elapsed time=  0.05673199793067407 s
# <------------------------------->
#
#
# Actual:  VRPJS
# Predicted: 5VQ4
#
# Elapsed time=  0.029178060189521737 s
# <------------------------------->
#
#
# Actual:  QGP5V
# Predicted: QGP5V
#
# Elapsed time=  0.885981922117344 s
# <------------------------------->
#
#
# Actual:  SRVHX3
# Predicted: M455
#
# Elapsed time=  0.2713285301352606 s
# <------------------------------->
#
#
# Actual:  5VJX
# Predicted: 5VJX
#
# Elapsed time=  0.6635069808695039 s
# <------------------------------->
#
#
# Actual:  W56Q
# Predicted: W56Q
#
# Elapsed time=  0.19617452923884804 s
# <------------------------------->
#
#
# Actual:  NQ4dP
# Predicted: NQ4dP
#
# Elapsed time=  0.7831295255889015 s
# <------------------------------->
#
#
# Actual:  VRH345
# Predicted: S3LL
#
# Elapsed time=  0.6577321044120042 s
# <------------------------------->
#
#
# Actual:  5X44
# Predicted: 5X44
#
# Elapsed time=  0.1380895332385199 s
# <------------------------------->
#
#
# Actual:  3VLR
# Predicted: 3VLR
#
# Elapsed time=  0.212536414402839 s
# <------------------------------->
#
#
# Actual:  GYJPPy
# Predicted: GYJPPy
#
# Elapsed time=  0.8954273080986592 s
# <------------------------------->
#
#
# Actual:  VXJLWD
# Predicted: VXJLWD
#
# Elapsed time=  0.5008574907521897 s
# <------------------------------->
#
#
# Actual:  YQWVW
# Predicted: RNXd
#
# Elapsed time=  0.16418015632557437 s
# <------------------------------->
#
#
# Actual:  P3PXXP
# Predicted: P3PXXP
#
# Elapsed time=  0.3239786609306098 s
# <------------------------------->
#
#
# Actual:  yNGQ4Y
# Predicted: yNGQ4Y
#
# Elapsed time=  0.08881377027381276 s
# <------------------------------->
#
#
# Actual:  QQXX
# Predicted: X5VK
#
# Elapsed time=  0.14543167135526858 s
# <------------------------------->
#
#
# Actual:  VP4Yd
# Predicted: VP4Yd
#
# Elapsed time=  0.464216868891163 s
# <------------------------------->
#
#
# Actual:  SX6Yd
# Predicted: y5SV
#
# Elapsed time=  0.8134585503021128 s
# <------------------------------->
#
#
# Actual:  QWJY53
# Predicted: QWJY53
#
# Elapsed time=  0.2600711138689461 s
# <------------------------------->
#
#
# Actual:  6PW4
# Predicted: 6PW4
#
# Elapsed time=  0.2866335031292241 s
# <------------------------------->
#
#
# Actual:  4SWWS
# Predicted: 4SWWS
#
# Elapsed time=  0.1565765455965299 s
# <------------------------------->
#
#
# Actual:  ddY3yS
# Predicted: VNP5
#
# Elapsed time=  0.9016837621061105 s
# <------------------------------->
#
#
# Actual:  KXXWd
# Predicted: KXXWd
#
# Elapsed time=  0.3978269211859278 s
# <------------------------------->
#
#
# Actual:  KPPX5
# Predicted: KPPX5
#
# Elapsed time=  0.5264753760477588 s
# <------------------------------->
#
#
# Actual:  MNDLWK
# Predicted: S5NY
#
# Elapsed time=  0.4551478441184631 s
# <------------------------------->
#
#
# Actual:  WRPS
# Predicted: WRPS
#
# Elapsed time=  0.27773187373289454 s
# <------------------------------->
#
#
# Actual:  DQdJW
# Predicted: PyMK
#
# Elapsed time=  0.5484902625287581 s
# <------------------------------->
#
#
# Actual:  MYSP
# Predicted: RLLQ
#
# Elapsed time=  0.787981798863822 s
# <------------------------------->
#
#
# Actual:  ND554
# Predicted: NPdG
#
# Elapsed time=  0.5576755004606812 s
# <------------------------------->
#
#
# Actual:  HWRMM
# Predicted: HWRMM
#
# Elapsed time=  0.805878141967781 s
# <------------------------------->
#
#
# Actual:  SQP6
# Predicted: SQP6
#
# Elapsed time=  0.31035700393330945 s
# <------------------------------->
#
#
# Actual:  3VN5WQ
# Predicted: 3VN5WQ
#
# Elapsed time=  0.9564918816964355 s
# <------------------------------->
#
#
# Actual:  KPGK
# Predicted: KPGK
#
# Elapsed time=  0.8245070739079234 s
# <------------------------------->
#
#
# Actual:  V66M
# Predicted: V66M
#
# Elapsed time=  0.8026374794607023 s
# <------------------------------->
#
#
# Actual:  3PSQ
# Predicted: GQ3D
#
# Elapsed time=  0.7745974344230674 s
# <------------------------------->
#
#
# Actual:  KSPG5
# Predicted: QDMH
#
# Elapsed time=  0.7424447175625758 s
# <------------------------------->
#
#
# Actual:  XXLW
# Predicted: XXLW
#
# Elapsed time=  0.9451630851085954 s
# <------------------------------->
#
#
# Actual:  5dMXdD
# Predicted: MW4Y
#
# Elapsed time=  0.9700295604258568 s
# <------------------------------->
#
#
# Actual:  N54LP
# Predicted: N54LP
#
# Elapsed time=  0.8276922664460767 s
# <------------------------------->
#
#
# Actual:  VWNLG
# Predicted: WXLS
#
# Elapsed time=  0.8174103386246362 s
# <------------------------------->
#
#
# Actual:  PKKdX
# Predicted: 3YdR
#
# Elapsed time=  0.7856804727614466 s
# <------------------------------->
#
#
# Actual:  G5MRLW
# Predicted: G5MRLW
#
# Elapsed time=  0.9289210792184321 s
# <------------------------------->
#
#
# Actual:  NQ4dP
# Predicted: JL56
#
# Elapsed time=  0.19505448277243465 s
# <------------------------------->
#
#
# Actual:  Y3PPR
# Predicted: QV5Y
#
# Elapsed time=  0.8234802716329033 s
# <------------------------------->
#
#
# Actual:  VPVSW
# Predicted: VPVSW
#
# Elapsed time=  0.6558394248692268 s
# <------------------------------->
#
#
# Actual:  V66M
# Predicted: LRPG
#
# Elapsed time=  0.12604504539651695 s
# <------------------------------->
#
#
# Actual:  P3PXXP
# Predicted: YQ6X
#
# Elapsed time=  0.03980601800318351 s
# <------------------------------->
#
#
# Actual:  VV5R
# Predicted: WdWM
#
# Elapsed time=  0.6094020396512113 s
# <------------------------------->
#
#
# Actual:  yVYXK
# Predicted: yVYXK
#
# Elapsed time=  0.41812599752893753 s
# <------------------------------->
#
#
# Actual:  RSR6V
# Predicted: XQXG
#
# Elapsed time=  0.9441886943815864 s
# <------------------------------->
#
#
# Actual:  SLML
# Predicted: SLML
#
# Elapsed time=  0.060307240273113405 s
# <------------------------------->
#
#
# Actual:  HPQGD
# Predicted: HPQGD
#
# Elapsed time=  0.2708785273708424 s
# <------------------------------->
#
#
# Actual:  P6VN
# Predicted: D6d5
#
# Elapsed time=  0.1232358911290744 s
# <------------------------------->
#
#
# Actual:  G3X5
# Predicted: G3X5
#
# Elapsed time=  0.9172110839181459 s
# <------------------------------->
#
#
# Actual:  dDD4KJ
# Predicted: dDD4KJ
#
# Elapsed time=  0.23527925377042302 s
# <------------------------------->
#
#
# Actual:  XSN3
# Predicted: XSN3
#
# Elapsed time=  0.4680140419728154 s
# <------------------------------->
#
#
# Actual:  WVSWSW
# Predicted: QHHS
#
# Elapsed time=  0.03871938245782558 s
# <------------------------------->
#
#
# Actual:  dKKW
# Predicted: VLRM
#
# Elapsed time=  0.06430990145029969 s
# <------------------------------->
#
#
# Actual:  3XPLL
# Predicted: 3XPLL
#
# Elapsed time=  0.8473302928625603 s
# <------------------------------->
#
#
# Actual:  PdMY
# Predicted: XQGR
#
# Elapsed time=  0.2147453240479793 s
# <------------------------------->
#
#
# Actual:  QGP5V
# Predicted: NYRD
#
# Elapsed time=  0.7944597160458213 s
# <------------------------------->
#
#
# Actual:  MVSJW
# Predicted: MVSJW
#
# Elapsed time=  0.6708285177642466 s
# <------------------------------->
#
#
# Actual:  YXyMXQ
# Predicted: Y6dQ
#
# Elapsed time=  0.4299010309883551 s
# <------------------------------->
#
#
# Actual:  HWDLS
# Predicted: PJM5
#
# Elapsed time=  0.38877049258096474 s
# <------------------------------->
#
#
# Actual:  MRVyXW
# Predicted: MRVyXW
#
# Elapsed time=  0.7267742153483155 s
# <------------------------------->
#
#
# Actual:  DYRW
# Predicted: DYRW
#
# Elapsed time=  0.7282436635222765 s
# <------------------------------->
#
#
# Actual:  KPPX5
# Predicted: RRGR
#
# Elapsed time=  0.5574621413239227 s
# <------------------------------->
#
#
# Actual:  MYVNSD
# Predicted: MYVNSD
#
# Elapsed time=  0.8383132007681181 s
# <------------------------------->
#
#
# Actual:  PK5K
# Predicted: y5GP
#
# Elapsed time=  0.5479736850543367 s
# <------------------------------->
#
#
# Actual:  MdQWd
# Predicted: MdQWd
#
# Elapsed time=  0.3634762421786448 s
# <------------------------------->
#
#
# Actual:  KPRWVy
# Predicted: 5ydH
#
# Elapsed time=  0.8702403938714115 s
# <------------------------------->
#
#
# Actual:  QQS3
# Predicted: QQS3
#
# Elapsed time=  0.8462997636502885 s
# <------------------------------->
#
#
# Actual:  SWYV
# Predicted: SWYV
#
# Elapsed time=  0.6256496905586707 s
# <------------------------------->
#
#
# Actual:  5HXG
# Predicted: 5HXG
#
# Elapsed time=  0.9483216199614097 s
# <------------------------------->
#
#
# Actual:  JLKDH
# Predicted: WPSD
#
# Elapsed time=  0.55765526922897 s
# <------------------------------->
#
#
# Actual:  H4KXS
# Predicted: P5PP
#
# Elapsed time=  0.9470995169337745 s
# <------------------------------->
#
#
# Actual:  X3M6V
# Predicted: X3M6V
#
# Elapsed time=  0.5093947553379221 s
# <------------------------------->
#
#
# Actual:  MdQWd
# Predicted: MdQWd
#
# Elapsed time=  0.11082962524898332 s
# <------------------------------->
#
#
# Actual:  YXMK
# Predicted: YXMK
#
# Elapsed time=  0.18514197747937777 s
# <------------------------------->
#
#
# Actual:  XVWPY
# Predicted: JYNL
#
# Elapsed time=  0.6987667574165861 s
# <------------------------------->
#
#
# Actual:  S5QPV
# Predicted: S5QPV
#
# Elapsed time=  0.3163611631803558 s
# <------------------------------->
#
#
# Actual:  QXLYRK
# Predicted: QXLYRK
#
# Elapsed time=  0.3109745677277701 s
# <------------------------------->
#
#
# Actual:  KVSPW
# Predicted: KVSPW
#
# Elapsed time=  0.4934816668767511 s
# <------------------------------->
#
#
# Actual:  SYKKK
# Predicted: GyNd
#
# Elapsed time=  0.4364114732236325 s
# <------------------------------->
#
#
# Actual:  MDPPRV
# Predicted: MDPPRV
#
# Elapsed time=  0.5521547688782105 s
# <------------------------------->
#
#
# Actual:  PSPH
# Predicted: 5YGH
#
# Elapsed time=  0.06101822278794089 s
# <------------------------------->
#
#
# Actual:  VSXMS
# Predicted: VSXMS
#
# Elapsed time=  0.7791519918147761 s
# <------------------------------->
#
#
# Actual:  QWJY53
# Predicted: KNQ6
#
# Elapsed time=  0.40096926628612584 s
# <------------------------------->
#
#
# Actual:  SRVHX3
# Predicted: SRVHX3
#
# Elapsed time=  0.8242410905031986 s
# <------------------------------->
#
#
# Actual:  P5VYPJ
# Predicted: P5VYPJ
#
# Elapsed time=  0.973066529503162 s
# <------------------------------->
#
#
# Actual:  NLVLPH
# Predicted: WHS3
#
# Elapsed time=  0.5567680067557077 s
# <------------------------------->
#
#
# Actual:  QHSK
# Predicted: QHSK
#
# Elapsed time=  0.5964488041020743 s
# <------------------------------->
#
#
# Actual:  GdPyQH
# Predicted: GdPyQH
#
# Elapsed time=  0.2539032761605463 s
# <------------------------------->
#
#
# Actual:  VHVJKH
# Predicted: 4RQL
#
# Elapsed time=  0.9463347593023276 s
# <------------------------------->
#
#
# Actual:  5PGR
# Predicted: 5PGR
#
# Elapsed time=  0.6037554233590381 s
# <------------------------------->
#
#
# Actual:  JPVMSK
# Predicted: JPVMSK
#
# Elapsed time=  0.916376344168623 s
# <------------------------------->
#
#
# Actual:  d3KSR
# Predicted: PyXH
#
# Elapsed time=  0.22142258983475227 s
# <------------------------------->
#
#
# Actual:  QR5W
# Predicted: J6RH
#
# Elapsed time=  0.02691650788219313 s
# <------------------------------->
#
#
# Actual:  KY5VWd
# Predicted: KY5VWd
#
# Elapsed time=  0.06745233375572857 s
# <------------------------------->
#
#
# Actual:  Y6VWRQ
# Predicted: XQM3
#
# Elapsed time=  0.2965613444548054 s
# <------------------------------->
#
#
# Actual:  XWSJ
# Predicted: NYGP
#
# Elapsed time=  0.2398823449525599 s
# <------------------------------->
#
#
# Actual:  K4X3L
# Predicted: K4X3L
#
# Elapsed time=  0.04890980848389015 s
# <------------------------------->
#
#
# Actual:  6Hy6
# Predicted: 6Hy6
#
# Elapsed time=  0.9780788203621907 s
# <------------------------------->
#
#
# Actual:  VVPKG
# Predicted: PNJN
#
# Elapsed time=  0.7141245878413531 s
# <------------------------------->
#
#
# Actual:  RW6DJ
# Predicted: RW6DJ
#
# Elapsed time=  0.5691964620562631 s
# <------------------------------->
#
#
# Actual:  DQ5KS
# Predicted: NWPV
#
# Elapsed time=  0.39232656324078585 s
# <------------------------------->
#
#
# Actual:  6X33D
# Predicted: XSYR
#
# Elapsed time=  0.5775628333282635 s
# <------------------------------->
#
#
# Actual:  YPKW
# Predicted: YPKW
#
# Elapsed time=  0.10476201272920271 s
# <------------------------------->
#
#
# Actual:  QP5KNW
# Predicted: QP5KNW
#
# Elapsed time=  0.3329471089400835 s
# <------------------------------->
#
#
# Actual:  W3dN
# Predicted: KPSH
#
# Elapsed time=  0.09929481500742987 s
# <------------------------------->
#
#
# Actual:  dVXSD
# Predicted: dVXSD
#
# Elapsed time=  0.47770946910738965 s
# <------------------------------->
#
#
# Actual:  HX33M6
# Predicted: PLRJ
#
# Elapsed time=  0.7736171245702934 s
# <------------------------------->
#
#
# Actual:  dYDK
# Predicted: dYDK
#
# Elapsed time=  0.37985205506436226 s
# <------------------------------->
#
#
# Actual:  PXJG
# Predicted: YKVK
#
# Elapsed time=  0.7957838822298948 s
# <------------------------------->
#
#
# Actual:  GHKYV
# Predicted: PNdK
#
# Elapsed time=  0.6986723061916769 s
# <------------------------------->
#
#
# Actual:  W3MRX
# Predicted: y6H5
#
# Elapsed time=  0.4303787946538957 s
# <------------------------------->
#
#
# Actual:  SRR5YW
# Predicted: SRR5YW
#
# Elapsed time=  0.13778516712410604 s
# <------------------------------->
#
#
# Actual:  V34WYP
# Predicted: V34WYP
#
# Elapsed time=  0.020154473537372763 s
# <------------------------------->
#
#
# Actual:  XGSQ
# Predicted: JD33
#
# Elapsed time=  0.5543478001165555 s
# <------------------------------->
#
#
# Actual:  PDVWKK
# Predicted: DW5W
#
# Elapsed time=  0.10261610005199184 s
# <------------------------------->
#
#
# Actual:  Y3PPR
# Predicted: Y3PPR
#
# Elapsed time=  0.2098531331294079 s
# <------------------------------->
#
#
# Actual:  DYRW
# Predicted: DYRW
#
# Elapsed time=  0.30336985893259016 s
# <------------------------------->
#
#
# Actual:  3XPLL
# Predicted: NK6R
#
# Elapsed time=  0.026851538416355902 s
# <------------------------------->
#
#
# Actual:  dDD4KJ
# Predicted: dDD4KJ
#
# Elapsed time=  0.04112913262342199 s
# <------------------------------->
#
#
# Actual:  MNDLWK
# Predicted: MNDLWK
#
# Elapsed time=  0.618478836663921 s
# <------------------------------->
#
#
# Actual:  V34WYP
# Predicted: V34WYP
#
# Elapsed time=  0.3069372984882316 s
# <------------------------------->
#
#
# Actual:  WXLX
# Predicted: WXLX
#
# Elapsed time=  0.17501484155347924 s
# <------------------------------->
#
#
# Actual:  KWS53J
# Predicted: KWS53J
#
# Elapsed time=  0.5236565388784394 s
# <------------------------------->
#
#
# Actual:  WY3d5Q
# Predicted: 3GV4
#
# Elapsed time=  0.32855809969504124 s
# <------------------------------->
#
#
# Actual:  WNR3V
# Predicted: WNR3V
#
# Elapsed time=  0.49461851658169254 s
# <------------------------------->
#
#
# Actual:  NyD3yH
# Predicted: NyD3yH
#
# Elapsed time=  0.04793038203492472 s
# <------------------------------->
#
#
# Actual:  XKP4
# Predicted: 6QXL
#
# Elapsed time=  0.9606443865065027 s
# <------------------------------->
#
#
# Actual:  XVWPY
# Predicted: XVWPY
#
# Elapsed time=  0.8917373810343513 s
# <------------------------------->
#
#
# Actual:  VWWMJ
# Predicted: VWWMJ
#
# Elapsed time=  0.9124357455547359 s
# <------------------------------->
#
#
# Actual:  SWYV
# Predicted: JL54
#
# Elapsed time=  0.5965719204190642 s
# <------------------------------->
#
#
# Actual:  QWNWR
# Predicted: SXdR
#
# Elapsed time=  0.3938639763838129 s
# <------------------------------->
#
#
# Actual:  PVPW
# Predicted: PVPW
#
# Elapsed time=  0.8803954313731834 s
# <------------------------------->
#
#
# Actual:  6XSRVJ
# Predicted: 6XSRVJ
#
# Elapsed time=  0.06867753355175232 s
# <------------------------------->
#
#
# Actual:  QWDL
# Predicted: NXYY
#
# Elapsed time=  0.8520883719341917 s
# <------------------------------->
#
#
# Actual:  5GKY
# Predicted: 5JGW
#
# Elapsed time=  0.8352406735618323 s
# <------------------------------->
#
#
# Actual:  4LWWV6
# Predicted: DRPd
#
# Elapsed time=  0.4232355821217154 s
# <------------------------------->
#
#
# Actual:  KWPGP
# Predicted: MKXW
#
# Elapsed time=  0.2935579627718866 s
# <------------------------------->
#
#
# Actual:  PXVK
# Predicted: MGWQ
#
# Elapsed time=  0.13097658033259574 s
# <------------------------------->
# Total number of CAPTCHAS broken:  284
# Total number of CAPTCHAS attempted:  493
# Total time taken=  157.13586545424891 s
# Accuracy=  57.606490872210955
