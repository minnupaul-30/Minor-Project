# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import PIL
from PIL import Image, ImageOps
import os

# %%
def segment(filename, characters = []):
    for character in characters:
        try:
            # Create target Directory
            os.mkdir('./captcha_segmented/{}'.format(character))
            #print("Directory ",dirName," Created ") 
        except FileExistsError:
            continue
    #img = cv2.imread(filename, 0)
    #plt.imshow(img, 'gray')

    # Otsu thresholding
    #ret2, th2 = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    #plt.imshow(th2, 'gray')

    # Closing : Dilation + Erosion
    #kernel = np.ones((3,3), np.uint8)
    #closing = cv2.morphologyEx(th2, cv2.MORPH_CLOSE, kernel)

    #plt.imshow(closing, 'gray')

    # Dilation with a new kernel size.

    #kernel = np.ones((2,3), np.uint8)

    #final = cv2.dilate(closing, kernel, iterations=1)

    #plt.imshow(final, 'gray')

    #Drawing rectangles to test the borders of the characters to test the hardcoded cordinates.

    #x, y, w, h = 23, 5, 23, 45
    #for  i in range(5):
        #cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
        #cv2.rectangle(dilation, (x, y), (x + w, y + h), (0, 255, 0), 2)
    #    cv2.rectangle(final, (x, y), (x + w, y + h), (0, 255, 0), 2)
        #cv2.rectangle(dilation3, (x, y), (x + w, y + h), (0, 255, 0), 2)
    #    x += w


    #plt.imshow(final, 'gray')

    #image = PIL.Image.fromarray(filename)
    #image.save('segmented.png')

    imageobject = Image.open(filename)
    #plt.imshow(imageobject,'gray')

    x, y, w, h = 27, 5, 22, 50
    for  i in range(len(characters)):
        crop1 = imageobject.crop((x, y, x + w, y + h))
        im_final = crop1.crop((0,0,20,45))
        old_size = im_final.size
        desired_size = 50
        ratio = float(desired_size)/max(old_size)
        new_size = tuple([int(x*ratio) for x in old_size])
        delta_w = desired_size - new_size[0]
        delta_h = desired_size - new_size[1]
        padding = (delta_w//2, delta_h//2, delta_w-(delta_w//2), delta_h-(delta_h//2))
        new_im = ImageOps.expand(im_final, padding,fill=255)
        #plt.imshow(new_im)
        #crop1.show()
        #print(characters)
        num_files = len(os.listdir('./captcha_segmented/{}'.format(characters[i])))
        #print(num_files)
        #print(len(os.listdir('./captcha_segmented/{}'.format(characters[i]))))
        #print(num_files)
        crop1.save('./captcha_segmented/{}/{}.png'.format(characters[i],num_files+1))
        x += w
    #os.remove('segmented.png')




CAPTCHA_DIR = 'test'
try:
    os.mkdir('captcha_segmented')
except FileExistsError:
    pass
for captchas in os.listdir(CAPTCHA_DIR):
    if len(captchas) >1:
        captcha_path =os.path.join(CAPTCHA_DIR,captchas)
        initial = captchas.split('.')
        characters = list(initial[0])
        segment(captcha_path, characters)
