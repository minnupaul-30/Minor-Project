# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import import_ipynb
#import Segmentation
import time
import preds
# Out:
# importing Jupyter notebook from preds.ipynb
# importing Jupyter notebook from Captcha_seg.ipynb
# 1080
# /home/bg/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Train on 864 samples, validate on 216 samples
# Epoch 1/20
# 864/864 [==============================] - 7s 8ms/step - loss: 3.5886 - acc: 0.0347 - val_loss: 3.5834 - val_acc: 0.0278
# Epoch 2/20
# 864/864 [==============================] - 6s 7ms/step - loss: 3.5131 - acc: 0.0579 - val_loss: 3.3985 - val_acc: 0.0833
# Epoch 3/20
# 864/864 [==============================] - 6s 7ms/step - loss: 2.8466 - acc: 0.2037 - val_loss: 2.4855 - val_acc: 0.3102
# Epoch 4/20
# 864/864 [==============================] - 6s 7ms/step - loss: 1.7888 - acc: 0.4815 - val_loss: 1.7931 - val_acc: 0.5000
# Epoch 5/20
# 864/864 [==============================] - 6s 7ms/step - loss: 1.0969 - acc: 0.6644 - val_loss: 1.5945 - val_acc: 0.5972
# Epoch 6/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.6987 - acc: 0.7812 - val_loss: 1.6038 - val_acc: 0.5602
# Epoch 7/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.4616 - acc: 0.8669 - val_loss: 1.5347 - val_acc: 0.6250
# Epoch 8/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.2652 - acc: 0.9317 - val_loss: 1.5185 - val_acc: 0.6435
# Epoch 9/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.1805 - acc: 0.9502 - val_loss: 1.5971 - val_acc: 0.6296
# Epoch 10/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.1080 - acc: 0.9745 - val_loss: 1.8825 - val_acc: 0.6204
# Epoch 11/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.0704 - acc: 0.9826 - val_loss: 1.9216 - val_acc: 0.6435
# Epoch 12/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.0766 - acc: 0.9838 - val_loss: 1.8595 - val_acc: 0.6620
# Epoch 13/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.0704 - acc: 0.9826 - val_loss: 1.7425 - val_acc: 0.6759
# Epoch 14/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.0423 - acc: 0.9884 - val_loss: 2.0242 - val_acc: 0.6667
# Epoch 15/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.0483 - acc: 0.9838 - val_loss: 2.1098 - val_acc: 0.6620
# Epoch 16/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.1145 - acc: 0.9664 - val_loss: 1.6935 - val_acc: 0.6944
# Epoch 17/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.0942 - acc: 0.9676 - val_loss: 1.9800 - val_acc: 0.6713
# Epoch 18/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.1067 - acc: 0.9699 - val_loss: 1.6288 - val_acc: 0.7269
# Epoch 19/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.0478 - acc: 0.9861 - val_loss: 1.9442 - val_acc: 0.6991
# Epoch 20/20
# 864/864 [==============================] - 6s 7ms/step - loss: 0.0362 - acc: 0.9919 - val_loss: 1.7468 - val_acc: 0.6898

# %%
CATEGORIES = set()
names =[]
for i in os.listdir('test/'):
    names.append(i.split('.')[0])
for i in names:
    for x in list(i):
        CATEGORIES.add(x)
CATEGORIES=list(CATEGORIES)
print(CATEGORIES)
# Out:
# ['3', 'P', 'F', 'B', 'C', 'f', 'X', '7', 'V', 'K', 'b', '6', 'n', '8', 'm', 'q', 'M', 'e', 'G', 'N', 'R', 'Z', 'Y', 'h', 'W', 'H', '4', 'U', 'Q', 'd', 'A', 'a', 'E', 'y', 'S', '2', '5']

# %%
#print(len(train_data))

# %%
import random

#random.shuffle(train_data)

# %%
#for sample in train_data[:10]:
#    print(sample[1])

# %%
X = []
y = []

# %% [markdown]
# for features, label in train_data:
#     X.append(features)
#     y.append(label)
#
# X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %% [markdown]
# import pickle
#
# pickle_out = open("X.pickle", "wb")
# pickle.dump(X, pickle_out)
# pickle_out.close()
# pickle_out = open("y.pickle", "wb")
# pickle.dump(y, pickle_out)
# pickle_out.close()

# %% [markdown]
# pickle_in= open("X.pickle", "rb")
# X = pickle.load(pickle_in)
# X.shape[1:]

# %% [markdown]
# import tensorflow as tf
# from keras.models import Sequential
# from keras.layers import Dense, Dropout,Activation, Flatten, Conv2D, MaxPooling2D
#
# X = pickle.load(open("X.pickle","rb"))
# y = pickle.load(open("y.pickle","rb"))
#
# X = X/255.0
#
# model = Sequential()
#
# model.add(Conv2D(64,(3,3),input_shape= X.shape[1:]))
# model.add(Activation("relu"))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Conv2D(64,(3,3)))
# model.add(Activation("relu"))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Conv2D(64,(3,3)))
# model.add(Activation("relu"))
# model.add(MaxPooling2D(pool_size=(2,2)))
#
# model.add(Flatten())
# model.add(Dense(64))
# model.add(Activation("relu"))
#
#
# model.add(Dense(19))
# model.add(Activation("softmax"))
#
# from keras.utils import to_categorical
# y_binary = to_categorical(y)
#
# model.compile(loss="categorical_crossentropy",
#              optimizer="adam",
#              metrics=['accuracy'])
#
# model.fit(X,y_binary,batch_size=128, epochs=20, validation_split = 0.2)

# %%
#loss_value, metrics_value = model.evaluate(X,y_binary,batch_size=10)

# %%
#print(loss_value, metrics_value)

# %%
import random

# %%
def similarity(a,b):
    i =0
    for x,y in zip(a,b):
        if x==y:
            i+= 1
    percentage = (i/5) * 100
    return percentage

def prepare(filepath):
    IMG_SIZE = 50
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
    #plt.imshow(new_array,'gray')
    return new_array.reshape(-1, IMG_SIZE,IMG_SIZE,1)

total_time = 0
score = 0
count = 0
done = []
list_ = preds.predictions('test',CATEGORIES)
CAPTCHA_DIR = list_[0]
for x in CAPTCHA_DIR:
    captchas = random.choice(CAPTCHA_DIR)
    if captchas in done:
        continue
    else:
        done.append(captchas)
        start_time = time.time()
        predict_list= []
        print('\n')
        print('Actual: ',captchas[0][0])

        files = []
        for segments in list_:
            files.append(segments)

        #for segments in files:
        #    filepath = (SEGMENTS_DIR,segments)
        #    prediction = model.predict([prepare(filepath)])
        #    predict_list.append(CATEGORIES[np.argmax(prediction[0])])

        elapsed_time = time.time()-start_time
        time.sleep(captchas[1])
        total_time += elapsed_time
        final_prediction = ''.join(predict_list)
        #if captcha_name[0]== final_prediction:
        #    score +=1
        score = list_[1]
        print('Predicted:',captchas[0][1],'\n')
        print('Elapsed time= ',captchas[1],'s')
        total_time +=captchas[1]
        print('<------------------------------->')    
    

print('Total number of CAPTCHAS broken: ',score)    
print('Total number of CAPTCHAS attempted: ',len(list_[0]))
print('Total time taken= ',total_time,'s')
print('Accuracy= ', (score/len(list_[0])*100))
#model = tf.keras.models.load_model('captcha_alpha.model')
#prediction = model.predict([prepare('3.png')])
#print(len(prediction[0]))
#print(prediction[0])
#print(CATEGORIES[np.argmax(prediction[0])])
# Out:
# Actual:  PZSCV
# Predicted: PFF3
#
# Elapsed time=  0.479424253848621 s
# <------------------------------->
#
#
# Actual:  emafK
# Predicted: KyZP
#
# Elapsed time=  0.16978444152360406 s
# <------------------------------->
#
#
# Actual:  V7hCn
# Predicted: 6Kya
#
# Elapsed time=  0.46874237187209533 s
# <------------------------------->
#
#
# Actual:  ZSnPd
# Predicted: ZSnPd
#
# Elapsed time=  0.6413051947401001 s
# <------------------------------->
#
#
# Actual:  FCMSW
# Predicted: y8QW
#
# Elapsed time=  0.6795107561955209 s
# <------------------------------->
#
#
# Actual:  qKabb
# Predicted: VFd7
#
# Elapsed time=  0.6141975421329724 s
# <------------------------------->
#
#
# Actual:  XQZdA
# Predicted: XQZdA
#
# Elapsed time=  0.8042363744757965 s
# <------------------------------->
#
#
# Actual:  WbRXY
# Predicted: WbRXY
#
# Elapsed time=  0.517974010419938 s
# <------------------------------->
#
#
# Actual:  WqSSP
# Predicted: m4Sb
#
# Elapsed time=  0.8614470891320488 s
# <------------------------------->
#
#
# Actual:  2PKPK
# Predicted: eHd2
#
# Elapsed time=  0.7349626039065406 s
# <------------------------------->
#
#
# Actual:  Y2qVa
# Predicted: Y2qVa
#
# Elapsed time=  0.03962858603348074 s
# <------------------------------->
#
#
# Actual:  ePSCW
# Predicted: d5dm
#
# Elapsed time=  0.007492974613070191 s
# <------------------------------->
#
#
# Actual:  qVCXK
# Predicted: qVCXK
#
# Elapsed time=  0.8343791459751929 s
# <------------------------------->
#
#
# Actual:  VC7VV
# Predicted: CACA
#
# Elapsed time=  0.2591451329089778 s
# <------------------------------->
#
#
# Actual:  aSnnV
# Predicted: 74qU
#
# Elapsed time=  0.8222186154258712 s
# <------------------------------->
#
#
# Actual:  5SyCH
# Predicted: 5SyCH
#
# Elapsed time=  0.756014168885452 s
# <------------------------------->
#
#
# Actual:  RnSMd
# Predicted: RnSMd
#
# Elapsed time=  0.7291917219082843 s
# <------------------------------->
#
#
# Actual:  PQhXa
# Predicted: 7ahH
#
# Elapsed time=  0.3502112322297313 s
# <------------------------------->
#
#
# Actual:  HFNme
# Predicted: HFNme
#
# Elapsed time=  0.0906353072450089 s
# <------------------------------->
#
#
# Actual:  ddVUS
# Predicted: 2hSW
#
# Elapsed time=  0.16123431667565769 s
# <------------------------------->
#
#
# Actual:  f5FMZ
# Predicted: f5FMZ
#
# Elapsed time=  0.44031662608542854 s
# <------------------------------->
#
#
# Actual:  VHySS
# Predicted: aMmX
#
# Elapsed time=  0.4168648954041142 s
# <------------------------------->
#
#
# Actual:  a4V2a
# Predicted: AFM2
#
# Elapsed time=  0.4215331726491648 s
# <------------------------------->
#
#
# Actual:  qd7FV
# Predicted: qd7FV
#
# Elapsed time=  0.7992888804215046 s
# <------------------------------->
#
#
# Actual:  aFZXZ
# Predicted: WeNU
#
# Elapsed time=  0.7950728314023313 s
# <------------------------------->
#
#
# Actual:  7VKS7
# Predicted: 7VKS7
#
# Elapsed time=  0.9981112407049951 s
# <------------------------------->
#
#
# Actual:  ZRq8X
# Predicted: BaW3
#
# Elapsed time=  0.8377794842811725 s
# <------------------------------->
#
#
# Actual:  UGSXd
# Predicted: KCn2
#
# Elapsed time=  0.06940533263118431 s
# <------------------------------->
#
#
# Actual:  SqmKV
# Predicted: SqmKV
#
# Elapsed time=  0.31485201052523304 s
# <------------------------------->
#
#
# Actual:  QZEUS
# Predicted: KaC8
#
# Elapsed time=  0.007192426848145028 s
# <------------------------------->
#
#
# Actual:  8VMSS
# Predicted: 8VMSS
#
# Elapsed time=  0.09290375330983802 s
# <------------------------------->
#
#
# Actual:  ZamX6
# Predicted: HYfy
#
# Elapsed time=  0.8100667562705206 s
# <------------------------------->
#
#
# Actual:  RCnUP
# Predicted: RCnUP
#
# Elapsed time=  0.49106066824672645 s
# <------------------------------->
#
#
# Actual:  Z3QQU
# Predicted: Z3QQU
#
# Elapsed time=  0.4700554872950736 s
# <------------------------------->
#
#
# Actual:  dGAUB
# Predicted: dGAUB
#
# Elapsed time=  0.3000343059628263 s
# <------------------------------->
#
#
# Actual:  H46yN
# Predicted: H46yN
#
# Elapsed time=  0.25287765624213254 s
# <------------------------------->
#
#
# Actual:  hAfVX
# Predicted: hAfVX
#
# Elapsed time=  0.8659501397450106 s
# <------------------------------->
#
#
# Actual:  XU2PW
# Predicted: XU2PW
#
# Elapsed time=  0.06733721119824143 s
# <------------------------------->
#
#
# Actual:  GSY8a
# Predicted: FP3E
#
# Elapsed time=  0.9636146343980242 s
# <------------------------------->
#
#
# Actual:  KUCfV
# Predicted: KUCfV
#
# Elapsed time=  0.9130136093192195 s
# <------------------------------->
#
#
# Actual:  WMXdK
# Predicted: HR8d
#
# Elapsed time=  0.6953111993042975 s
# <------------------------------->
#
#
# Actual:  WfCh6
# Predicted: P4KM
#
# Elapsed time=  0.45120138045146385 s
# <------------------------------->
#
#
# Actual:  NCqVE
# Predicted: 8yEa
#
# Elapsed time=  0.7649599447715294 s
# <------------------------------->
#
#
# Actual:  XZUh8
# Predicted: 3nQU
#
# Elapsed time=  0.40282220303564065 s
# <------------------------------->
#
#
# Actual:  XSSAF
# Predicted: aa3X
#
# Elapsed time=  0.29100643406859705 s
# <------------------------------->
#
#
# Actual:  Z6KWV
# Predicted: 4FEG
#
# Elapsed time=  0.9216619068124571 s
# <------------------------------->
#
#
# Actual:  nbPUe
# Predicted: nbPUe
#
# Elapsed time=  0.660395085835446 s
# <------------------------------->
#
#
# Actual:  HNVVP
# Predicted: XdUe
#
# Elapsed time=  0.5480891157388409 s
# <------------------------------->
#
#
# Actual:  XU2K6
# Predicted: XU2K6
#
# Elapsed time=  0.537383148171318 s
# <------------------------------->
#
#
# Actual:  Y2qVa
# Predicted: YhUZ
#
# Elapsed time=  0.580615581343579 s
# <------------------------------->
#
#
# Actual:  FEQNH
# Predicted: FEQNH
#
# Elapsed time=  0.5298715242533935 s
# <------------------------------->
#
#
# Actual:  WQB5P
# Predicted: WQB5P
#
# Elapsed time=  0.1593330754897152 s
# <------------------------------->
#
#
# Actual:  Z2RCN
# Predicted: Z2RCN
#
# Elapsed time=  0.8499790503957463 s
# <------------------------------->
#
#
# Actual:  WyhU7
# Predicted: WyhU7
#
# Elapsed time=  0.1521095788130753 s
# <------------------------------->
#
#
# Actual:  6Qb5S
# Predicted: PPFd
#
# Elapsed time=  0.6115167024117503 s
# <------------------------------->
#
#
# Actual:  5V4ZP
# Predicted: 5V4ZP
#
# Elapsed time=  0.13305320994904446 s
# <------------------------------->
#
#
# Actual:  ZeKmV
# Predicted: 2nb7
#
# Elapsed time=  0.2861954180404095 s
# <------------------------------->
#
#
# Actual:  BW3Sb
# Predicted: MC2n
#
# Elapsed time=  0.5085325552092815 s
# <------------------------------->
#
#
# Actual:  UaUGe
# Predicted: UaUGe
#
# Elapsed time=  0.3312383423542291 s
# <------------------------------->
#
#
# Actual:  CNURP
# Predicted: 4P3m
#
# Elapsed time=  0.3312693705897811 s
# <------------------------------->
#
#
# Actual:  AySbb
# Predicted: yhVm
#
# Elapsed time=  0.0067903089643930326 s
# <------------------------------->
#
#
# Actual:  XXW76
# Predicted: XXW76
#
# Elapsed time=  0.7900017609167668 s
# <------------------------------->
#
#
# Actual:  KbqVF
# Predicted: KGRG
#
# Elapsed time=  0.5691941328293733 s
# <------------------------------->
#
#
# Actual:  f6daH
# Predicted: QY84
#
# Elapsed time=  0.14745481498272106 s
# <------------------------------->
#
#
# Actual:  eSmme
# Predicted: AY8G
#
# Elapsed time=  0.04838044035896827 s
# <------------------------------->
#
#
# Actual:  AAYSX
# Predicted: AAYSX
#
# Elapsed time=  0.2756433649645861 s
# <------------------------------->
#
#
# Actual:  yfhPe
# Predicted: yfhPe
#
# Elapsed time=  0.132584426136653 s
# <------------------------------->
#
#
# Actual:  7mbUP
# Predicted: SZeC
#
# Elapsed time=  0.4619466330946417 s
# <------------------------------->
#
#
# Actual:  nUPPQ
# Predicted: nUPPQ
#
# Elapsed time=  0.2579032169553064 s
# <------------------------------->
#
#
# Actual:  yfhPe
# Predicted: yfhPe
#
# Elapsed time=  0.10415400882093706 s
# <------------------------------->
#
#
# Actual:  yP7R2
# Predicted: yP7R2
#
# Elapsed time=  0.5837398198911472 s
# <------------------------------->
#
#
# Actual:  NnaWA
# Predicted: NnaWA
#
# Elapsed time=  0.4721480670016859 s
# <------------------------------->
#
#
# Actual:  7PUbe
# Predicted: 7Vem
#
# Elapsed time=  0.5328433776886451 s
# <------------------------------->
#
#
# Actual:  HaVVC
# Predicted: HaVVC
#
# Elapsed time=  0.9265108050671584 s
# <------------------------------->
#
#
# Actual:  AVEFS
# Predicted: KKYC
#
# Elapsed time=  0.4382412580291326 s
# <------------------------------->
#
#
# Actual:  CAy3C
# Predicted: CAy3C
#
# Elapsed time=  0.5744419005074215 s
# <------------------------------->
#
#
# Actual:  844MW
# Predicted: 844MW
#
# Elapsed time=  0.5297580645488106 s
# <------------------------------->
#
#
# Actual:  VebSX
# Predicted: VebSX
#
# Elapsed time=  0.36611051121456706 s
# <------------------------------->
#
#
# Actual:  eHA6K
# Predicted: VPNZ
#
# Elapsed time=  0.6443864590274044 s
# <------------------------------->
#
#
# Actual:  2PKPK
# Predicted: 2PKPK
#
# Elapsed time=  0.6546745492809432 s
# <------------------------------->
#
#
# Actual:  E2BVU
# Predicted: A6Q5
#
# Elapsed time=  0.9444231750536382 s
# <------------------------------->
#
#
# Actual:  257QZ
# Predicted: P3XH
#
# Elapsed time=  0.937573154513698 s
# <------------------------------->
#
#
# Actual:  5P5Pn
# Predicted: 3VCH
#
# Elapsed time=  0.2122544482541573 s
# <------------------------------->
#
#
# Actual:  V7VV6
# Predicted: BVny
#
# Elapsed time=  0.9054459096700607 s
# <------------------------------->
#
#
# Actual:  5WbZS
# Predicted: 5WbZS
#
# Elapsed time=  0.5521349292956219 s
# <------------------------------->
#
#
# Actual:  qMn8U
# Predicted: qMn8U
#
# Elapsed time=  0.4035481028594149 s
# <------------------------------->
#
#
# Actual:  5WbZS
# Predicted: 5WbZS
#
# Elapsed time=  0.1295034561102233 s
# <------------------------------->
#
#
# Actual:  SFbUW
# Predicted: BP8h
#
# Elapsed time=  0.8118048505252559 s
# <------------------------------->
#
#
# Actual:  qm4XQ
# Predicted: qm4XQ
#
# Elapsed time=  0.7876713057930543 s
# <------------------------------->
#
#
# Actual:  7qHVP
# Predicted: NyAR
#
# Elapsed time=  0.8902560354692998 s
# <------------------------------->
#
#
# Actual:  UaGd4
# Predicted: UaGd4
#
# Elapsed time=  0.9537217370862076 s
# <------------------------------->
#
#
# Actual:  UBhH3
# Predicted: UBhH3
#
# Elapsed time=  0.2770282871728247 s
# <------------------------------->
#
#
# Actual:  Z6KWV
# Predicted: Z6KWV
#
# Elapsed time=  0.12562692992529678 s
# <------------------------------->
#
#
# Actual:  EKXUP
# Predicted: FKX6
#
# Elapsed time=  0.588342101691884 s
# <------------------------------->
#
#
# Actual:  dCq6X
# Predicted: F8A7
#
# Elapsed time=  0.11604287403799318 s
# <------------------------------->
#
#
# Actual:  mUCXq
# Predicted: mUCXq
#
# Elapsed time=  0.20156873109405393 s
# <------------------------------->
#
#
# Actual:  ZamX6
# Predicted: ZamX6
#
# Elapsed time=  0.8252875673424936 s
# <------------------------------->
#
#
# Actual:  hX8Zn
# Predicted: hX8Zn
#
# Elapsed time=  0.1846295168946569 s
# <------------------------------->
#
#
# Actual:  3EFPn
# Predicted: QMSB
#
# Elapsed time=  0.3324845869018408 s
# <------------------------------->
#
#
# Actual:  hdHZ5
# Predicted: hdHZ5
#
# Elapsed time=  0.027762772336088926 s
# <------------------------------->
#
#
# Actual:  VKy75
# Predicted: VKy75
#
# Elapsed time=  0.9072184528710343 s
# <------------------------------->
#
#
# Actual:  nKWeb
# Predicted: nKWeb
#
# Elapsed time=  0.3313570879718295 s
# <------------------------------->
#
#
# Actual:  H46yN
# Predicted: EHyU
#
# Elapsed time=  0.6488890508897378 s
# <------------------------------->
#
#
# Actual:  bnCHq
# Predicted: bnCHq
#
# Elapsed time=  0.005101994912813823 s
# <------------------------------->
#
#
# Actual:  nbPUe
# Predicted: ZSPa
#
# Elapsed time=  0.17361891757973735 s
# <------------------------------->
#
#
# Actual:  2PKPK
# Predicted: 2PKPK
#
# Elapsed time=  0.49161858063924413 s
# <------------------------------->
#
#
# Actual:  qQHdW
# Predicted: XUVn
#
# Elapsed time=  0.13633156846288685 s
# <------------------------------->
#
#
# Actual:  KH573
# Predicted: V8W6
#
# Elapsed time=  0.07218930226705733 s
# <------------------------------->
#
#
# Actual:  5ZHZ8
# Predicted: QKnq
#
# Elapsed time=  0.2727336165802007 s
# <------------------------------->
#
#
# Actual:  BUV3h
# Predicted: 7aeK
#
# Elapsed time=  0.24148224791430506 s
# <------------------------------->
#
#
# Actual:  MMChY
# Predicted: MMChY
#
# Elapsed time=  0.4372373941907678 s
# <------------------------------->
#
#
# Actual:  SFbUW
# Predicted: SFbUW
#
# Elapsed time=  0.4313519380103732 s
# <------------------------------->
#
#
# Actual:  bd2NC
# Predicted: f3Ay
#
# Elapsed time=  0.5331519042252185 s
# <------------------------------->
#
#
# Actual:  VPXWG
# Predicted: CBGG
#
# Elapsed time=  0.4497698894240142 s
# <------------------------------->
#
#
# Actual:  P8A86
# Predicted: P8A86
#
# Elapsed time=  0.28509400855703215 s
# <------------------------------->
#
#
# Actual:  RBPnB
# Predicted: RBPnB
#
# Elapsed time=  0.10515020229596017 s
# <------------------------------->
#
#
# Actual:  ZSnEW
# Predicted: GhAF
#
# Elapsed time=  0.8432000361941038 s
# <------------------------------->
#
#
# Actual:  ZSnEW
# Predicted: ZSnEW
#
# Elapsed time=  0.9925516784432049 s
# <------------------------------->
#
#
# Actual:  fene4
# Predicted: fene4
#
# Elapsed time=  0.3999714773819183 s
# <------------------------------->
#
#
# Actual:  EYmhS
# Predicted: P7R8
#
# Elapsed time=  0.18024373048893272 s
# <------------------------------->
#
#
# Actual:  X7EUC
# Predicted: EmmY
#
# Elapsed time=  0.31074300567345503 s
# <------------------------------->
#
#
# Actual:  y3YAB
# Predicted: q3aQ
#
# Elapsed time=  0.5837797514019548 s
# <------------------------------->
#
#
# Actual:  CPBZ8
# Predicted: 2GHn
#
# Elapsed time=  0.9138206556564998 s
# <------------------------------->
#
#
# Actual:  CNKPb
# Predicted: CNKPb
#
# Elapsed time=  0.6474310356175706 s
# <------------------------------->
#
#
# Actual:  5WWVZ
# Predicted: bnG6
#
# Elapsed time=  0.14423572630458503 s
# <------------------------------->
#
#
# Actual:  RVny4
# Predicted: RfUB
#
# Elapsed time=  0.20457794793597972 s
# <------------------------------->
#
#
# Actual:  SdFRE
# Predicted: SdFRE
#
# Elapsed time=  0.3257742153033448 s
# <------------------------------->
#
#
# Actual:  3nKXq
# Predicted: 4NqB
#
# Elapsed time=  0.7742131148905588 s
# <------------------------------->
#
#
# Actual:  UnCHb
# Predicted: UnCHb
#
# Elapsed time=  0.8629694850293985 s
# <------------------------------->
#
#
# Actual:  XSeWQ
# Predicted: XSeWQ
#
# Elapsed time=  0.9697542918394727 s
# <------------------------------->
#
#
# Actual:  R2eWA
# Predicted: PVyV
#
# Elapsed time=  0.37800617838618344 s
# <------------------------------->
#
#
# Actual:  hUyAV
# Predicted: BBSZ
#
# Elapsed time=  0.1789965702469859 s
# <------------------------------->
#
#
# Actual:  KCA6R
# Predicted: VCAM
#
# Elapsed time=  0.9680863890498115 s
# <------------------------------->
#
#
# Actual:  VmnKW
# Predicted: SeKF
#
# Elapsed time=  0.3036470694688237 s
# <------------------------------->
#
#
# Actual:  KZ2SP
# Predicted: KZ2SP
#
# Elapsed time=  0.36035630504832594 s
# <------------------------------->
#
#
# Actual:  XdK2m
# Predicted: nfKQ
#
# Elapsed time=  0.0864100449760935 s
# <------------------------------->
#
#
# Actual:  N33dV
# Predicted: mW5M
#
# Elapsed time=  0.08447043419342182 s
# <------------------------------->
#
#
# Actual:  CQNZE
# Predicted: VGYY
#
# Elapsed time=  0.14474696863789727 s
# <------------------------------->
#
#
# Actual:  CPRUb
# Predicted: CPRUb
#
# Elapsed time=  0.016658941158713025 s
# <------------------------------->
#
#
# Actual:  SZPXU
# Predicted: 7ZVd
#
# Elapsed time=  0.7761642889330319 s
# <------------------------------->
#
#
# Actual:  dUqEQ
# Predicted: yXYb
#
# Elapsed time=  0.0682736179968404 s
# <------------------------------->
#
#
# Actual:  RSWeG
# Predicted: RSWeG
#
# Elapsed time=  0.4020712005104684 s
# <------------------------------->
#
#
# Actual:  afUn7
# Predicted: afUn7
#
# Elapsed time=  0.7192635563110972 s
# <------------------------------->
#
#
# Actual:  WyhU7
# Predicted: WdHW
#
# Elapsed time=  0.32327891203966364 s
# <------------------------------->
#
#
# Actual:  KZCmV
# Predicted: 6qCm
#
# Elapsed time=  0.7609880724681641 s
# <------------------------------->
#
#
# Actual:  ZSnPd
# Predicted: H7BQ
#
# Elapsed time=  0.33379890542825197 s
# <------------------------------->
#
#
# Actual:  AAYSX
# Predicted: PaQG
#
# Elapsed time=  0.8536999013969206 s
# <------------------------------->
#
#
# Actual:  fQSKN
# Predicted: fQSKN
#
# Elapsed time=  0.89897664659624 s
# <------------------------------->
#
#
# Actual:  QS75V
# Predicted: 4aQA
#
# Elapsed time=  0.7615121965880828 s
# <------------------------------->
#
#
# Actual:  ZVS2V
# Predicted: ZVS2V
#
# Elapsed time=  0.46357382143590176 s
# <------------------------------->
#
#
# Actual:  SFbUW
# Predicted: SFbUW
#
# Elapsed time=  0.8925732987728707 s
# <------------------------------->
#
#
# Actual:  FAS3C
# Predicted: FAS3C
#
# Elapsed time=  0.9871077168063032 s
# <------------------------------->
#
#
# Actual:  qSPGC
# Predicted: qSPGC
#
# Elapsed time=  0.989786347813363 s
# <------------------------------->
#
#
# Actual:  bKCGd
# Predicted: XAy8
#
# Elapsed time=  0.9356935580166676 s
# <------------------------------->
#
#
# Actual:  2YFGC
# Predicted: 2YFGC
#
# Elapsed time=  0.9002254789908173 s
# <------------------------------->
#
#
# Actual:  8nNZP
# Predicted: 8nNZP
#
# Elapsed time=  0.6075005120295535 s
# <------------------------------->
#
#
# Actual:  CAy3C
# Predicted: 8BnH
#
# Elapsed time=  0.19134483830425553 s
# <------------------------------->
#
#
# Actual:  S7SH5
# Predicted: B3PY
#
# Elapsed time=  0.10078645348151682 s
# <------------------------------->
#
#
# Actual:  UdYCH
# Predicted: UdYCH
#
# Elapsed time=  0.08068932998134115 s
# <------------------------------->
#
#
# Actual:  7GCFW
# Predicted: SaYb
#
# Elapsed time=  0.7100017889360363 s
# <------------------------------->
#
#
# Actual:  Q2Vdm
# Predicted: Q2Vdm
#
# Elapsed time=  0.37451627130205845 s
# <------------------------------->
#
#
# Actual:  UMy8U
# Predicted: N5Rd
#
# Elapsed time=  0.15733154838237007 s
# <------------------------------->
#
#
# Actual:  fhXY8
# Predicted: NXnd
#
# Elapsed time=  0.8303804149699661 s
# <------------------------------->
#
#
# Actual:  54Q5X
# Predicted: 54Q5X
#
# Elapsed time=  0.668054271517443 s
# <------------------------------->
#
#
# Actual:  ad3qY
# Predicted: 737Z
#
# Elapsed time=  0.4699994823590731 s
# <------------------------------->
#
#
# Actual:  KmAXG
# Predicted: KqRd
#
# Elapsed time=  0.6553844044709402 s
# <------------------------------->
#
#
# Actual:  ZP28V
# Predicted: ZP28V
#
# Elapsed time=  0.3807879467164781 s
# <------------------------------->
#
#
# Actual:  PaZy6
# Predicted: Xm3m
#
# Elapsed time=  0.8756781916722651 s
# <------------------------------->
#
#
# Actual:  WfZKH
# Predicted: 2UYU
#
# Elapsed time=  0.887333872136812 s
# <------------------------------->
#
#
# Actual:  PK3nA
# Predicted: P3CF
#
# Elapsed time=  0.10436119032960367 s
# <------------------------------->
#
#
# Actual:  UqNMQ
# Predicted: ZZbh
#
# Elapsed time=  0.5552424929419508 s
# <------------------------------->
#
#
# Actual:  CAbHR
# Predicted: 6aye
#
# Elapsed time=  0.5621052625704804 s
# <------------------------------->
#
#
# Actual:  PWndy
# Predicted: qBK8
#
# Elapsed time=  0.8464400667037785 s
# <------------------------------->
#
#
# Actual:  SqPfF
# Predicted: 4BC7
#
# Elapsed time=  0.6562077924073517 s
# <------------------------------->
#
#
# Actual:  AKXK2
# Predicted: fdQU
#
# Elapsed time=  0.25598334018245583 s
# <------------------------------->
#
#
# Actual:  2QRPU
# Predicted: NXNy
#
# Elapsed time=  0.798865022046514 s
# <------------------------------->
#
#
# Actual:  hB3Uq
# Predicted: 82bB
#
# Elapsed time=  0.5522929446043723 s
# <------------------------------->
#
#
# Actual:  A3d5y
# Predicted: mKQW
#
# Elapsed time=  0.32746488796107875 s
# <------------------------------->
#
#
# Actual:  XSeWQ
# Predicted: YKRE
#
# Elapsed time=  0.028748908973475595 s
# <------------------------------->
#
#
# Actual:  ad3qY
# Predicted: ad3qY
#
# Elapsed time=  0.6907691422375447 s
# <------------------------------->
#
#
# Actual:  YRdfG
# Predicted: Y3fH
#
# Elapsed time=  0.563238545505713 s
# <------------------------------->
#
#
# Actual:  VPXWG
# Predicted: VPXWG
#
# Elapsed time=  0.6853381958524816 s
# <------------------------------->
#
#
# Actual:  FaQCG
# Predicted: e6eM
#
# Elapsed time=  0.6812443108791392 s
# <------------------------------->
#
#
# Actual:  RX7Vn
# Predicted: RX7Vn
#
# Elapsed time=  0.510261784905126 s
# <------------------------------->
#
#
# Actual:  QH5FB
# Predicted: QH5FB
#
# Elapsed time=  0.1530863743990144 s
# <------------------------------->
#
#
# Actual:  2dhRS
# Predicted: QeVM
#
# Elapsed time=  0.8858143768902832 s
# <------------------------------->
#
#
# Actual:  Z3QQU
# Predicted: Z3QQU
#
# Elapsed time=  0.5683325094363443 s
# <------------------------------->
#
#
# Actual:  NnaWA
# Predicted: NnaWA
#
# Elapsed time=  0.20953538845903008 s
# <------------------------------->
#
#
# Actual:  MHUhN
# Predicted: MHUhN
#
# Elapsed time=  0.6756299178339945 s
# <------------------------------->
#
#
# Actual:  EbUhW
# Predicted: EMNy
#
# Elapsed time=  0.05553202354268871 s
# <------------------------------->
#
#
# Actual:  CUUhf
# Predicted: aVPH
#
# Elapsed time=  0.17748055349017333 s
# <------------------------------->
#
#
# Actual:  PP7fV
# Predicted: PP7fV
#
# Elapsed time=  0.6637439183437377 s
# <------------------------------->
#
#
# Actual:  Ce6YM
# Predicted: qBaS
#
# Elapsed time=  0.6181758453193145 s
# <------------------------------->
#
#
# Actual:  nCM64
# Predicted: nCM64
#
# Elapsed time=  0.8053085693100956 s
# <------------------------------->
#
#
# Actual:  EZQU6
# Predicted: EZQU6
#
# Elapsed time=  0.885791446124752 s
# <------------------------------->
#
#
# Actual:  bnCHq
# Predicted: bnCHq
#
# Elapsed time=  0.660140719562666 s
# <------------------------------->
#
#
# Actual:  Z2RCN
# Predicted: V32E
#
# Elapsed time=  0.988815039547274 s
# <------------------------------->
#
#
# Actual:  S2ENZ
# Predicted: aNAF
#
# Elapsed time=  0.24733639901694915 s
# <------------------------------->
#
#
# Actual:  CbZqA
# Predicted: N42b
#
# Elapsed time=  0.6286413487128164 s
# <------------------------------->
#
#
# Actual:  WQCYP
# Predicted: XCZU
#
# Elapsed time=  0.8527986789647982 s
# <------------------------------->
#
#
# Actual:  AZRBA
# Predicted: AZRBA
#
# Elapsed time=  0.6520828552340906 s
# <------------------------------->
#
#
# Actual:  eQA37
# Predicted: eQA37
#
# Elapsed time=  0.8939165874178341 s
# <------------------------------->
#
#
# Actual:  XU2K6
# Predicted: UPd6
#
# Elapsed time=  0.7194040230933123 s
# <------------------------------->
#
#
# Actual:  fSV2K
# Predicted: Ey4b
#
# Elapsed time=  0.34816875656361745 s
# <------------------------------->
#
#
# Actual:  bKBmG
# Predicted: KKEn
#
# Elapsed time=  0.9108005083906542 s
# <------------------------------->
#
#
# Actual:  3FVH3
# Predicted: 3FVH3
#
# Elapsed time=  0.22769792032591263 s
# <------------------------------->
#
#
# Actual:  hX8Zn
# Predicted: eRSW
#
# Elapsed time=  0.6018623885762681 s
# <------------------------------->
#
#
# Actual:  QnEX3
# Predicted: dBSm
#
# Elapsed time=  0.2610287478045511 s
# <------------------------------->
#
#
# Actual:  5FS8P
# Predicted: S3G6
#
# Elapsed time=  0.24410708788708946 s
# <------------------------------->
#
#
# Actual:  ZRq8X
# Predicted: ZRq8X
#
# Elapsed time=  0.7648218893187341 s
# <------------------------------->
#
#
# Actual:  SPEY8
# Predicted: SPEY8
#
# Elapsed time=  0.9759644350826048 s
# <------------------------------->
#
#
# Actual:  5dZPZ
# Predicted: Ad6W
#
# Elapsed time=  0.6959443614397156 s
# <------------------------------->
#
#
# Actual:  eSmme
# Predicted: eSmme
#
# Elapsed time=  0.07027863318825323 s
# <------------------------------->
#
#
# Actual:  ZSaP6
# Predicted: ZSaP6
#
# Elapsed time=  0.7780961160786916 s
# <------------------------------->
#
#
# Actual:  4SSSm
# Predicted: 33hn
#
# Elapsed time=  0.9995639690871287 s
# <------------------------------->
#
#
# Actual:  WWX7V
# Predicted: Rb8B
#
# Elapsed time=  0.4684137197633146 s
# <------------------------------->
#
#
# Actual:  ymyUV
# Predicted: ymyUV
#
# Elapsed time=  0.5470201574911973 s
# <------------------------------->
#
#
# Actual:  nbyMU
# Predicted: qybh
#
# Elapsed time=  0.59226467020512 s
# <------------------------------->
#
#
# Actual:  ZhSUm
# Predicted: UaRq
#
# Elapsed time=  0.5446435723543666 s
# <------------------------------->
#
#
# Actual:  qN6PB
# Predicted: qN6PB
#
# Elapsed time=  0.45744998180782737 s
# <------------------------------->
#
#
# Actual:  SPEXm
# Predicted: b78K
#
# Elapsed time=  0.06929012793570144 s
# <------------------------------->
#
#
# Actual:  UqNMQ
# Predicted: UqNMQ
#
# Elapsed time=  0.4946249332875554 s
# <------------------------------->
#
#
# Actual:  CNKPb
# Predicted: GeCK
#
# Elapsed time=  0.3733246373262673 s
# <------------------------------->
#
#
# Actual:  FV8eQ
# Predicted: FV8eQ
#
# Elapsed time=  0.9006798738677987 s
# <------------------------------->
#
#
# Actual:  2fUhX
# Predicted: 2fUhX
#
# Elapsed time=  0.5473159346203794 s
# <------------------------------->
#
#
# Actual:  afUn7
# Predicted: afUn7
#
# Elapsed time=  0.21380847473418063 s
# <------------------------------->
#
#
# Actual:  hdHZ5
# Predicted: hdHZ5
#
# Elapsed time=  0.912734392801253 s
# <------------------------------->
#
#
# Actual:  qQHdW
# Predicted: qQHdW
#
# Elapsed time=  0.9797822265223382 s
# <------------------------------->
#
#
# Actual:  S4mCb
# Predicted: MGZ4
#
# Elapsed time=  0.40844129906689286 s
# <------------------------------->
#
#
# Actual:  4mbyd
# Predicted: 4mbyd
#
# Elapsed time=  0.6130218034522668 s
# <------------------------------->
#
#
# Actual:  844MW
# Predicted: SBSb
#
# Elapsed time=  0.2710588523214953 s
# <------------------------------->
#
#
# Actual:  W5fX2
# Predicted: AmPP
#
# Elapsed time=  0.765643789109438 s
# <------------------------------->
#
#
# Actual:  Z74UV
# Predicted: bK3H
#
# Elapsed time=  0.1696518765402898 s
# <------------------------------->
#
#
# Actual:  f5FMZ
# Predicted: f5FMZ
#
# Elapsed time=  0.1000204321935746 s
# <------------------------------->
#
#
# Actual:  BdX46
# Predicted: BdX46
#
# Elapsed time=  0.6989547005774143 s
# <------------------------------->
#
#
# Actual:  8EXGS
# Predicted: yBn2
#
# Elapsed time=  0.6929716358709586 s
# <------------------------------->
#
#
# Actual:  HEUMZ
# Predicted: FXeW
#
# Elapsed time=  0.7828209060799803 s
# <------------------------------->
#
#
# Actual:  KUCfV
# Predicted: V6Za
#
# Elapsed time=  0.2839942899639397 s
# <------------------------------->
#
#
# Actual:  7f2Ke
# Predicted: WPBe
#
# Elapsed time=  0.646544126681818 s
# <------------------------------->
#
#
# Actual:  PahKF
# Predicted: KEdQ
#
# Elapsed time=  0.1962454878851152 s
# <------------------------------->
#
#
# Actual:  862U7
# Predicted: 862U7
#
# Elapsed time=  0.8622777855951564 s
# <------------------------------->
#
#
# Actual:  7qqEU
# Predicted: 7qqEU
#
# Elapsed time=  0.29530029912380074 s
# <------------------------------->
#
#
# Actual:  aV5Fa
# Predicted: SZF8
#
# Elapsed time=  0.1346389428247735 s
# <------------------------------->
#
#
# Actual:  Wn8PW
# Predicted: Wn8PW
#
# Elapsed time=  0.6087493231227086 s
# <------------------------------->
#
#
# Actual:  hUV5W
# Predicted: MeG8
#
# Elapsed time=  0.2871017248093145 s
# <------------------------------->
#
#
# Actual:  mUCXq
# Predicted: 35BU
#
# Elapsed time=  0.9495009884139504 s
# <------------------------------->
#
#
# Actual:  C7y3B
# Predicted: C7y3B
#
# Elapsed time=  0.10624481888386694 s
# <------------------------------->
#
#
# Actual:  A3d5y
# Predicted: A3d5y
#
# Elapsed time=  0.22854214679829044 s
# <------------------------------->
#
#
# Actual:  dEPKK
# Predicted: C4K6
#
# Elapsed time=  0.9915746094964272 s
# <------------------------------->
#
#
# Actual:  CeXVy
# Predicted: hFWP
#
# Elapsed time=  0.2729618729213651 s
# <------------------------------->
#
#
# Actual:  Y5q5b
# Predicted: 8dQm
#
# Elapsed time=  0.6181056465940017 s
# <------------------------------->
#
#
# Actual:  XXEPW
# Predicted: GKRn
#
# Elapsed time=  0.8886585882134435 s
# <------------------------------->
#
#
# Actual:  a4SGN
# Predicted: a4SGN
#
# Elapsed time=  0.24944593363037926 s
# <------------------------------->
#
#
# Actual:  CX8SN
# Predicted: CX8SN
#
# Elapsed time=  0.6185292767634003 s
# <------------------------------->
#
#
# Actual:  V7ZVE
# Predicted: HKRF
#
# Elapsed time=  0.41103769033826376 s
# <------------------------------->
#
#
# Actual:  PVbVC
# Predicted: qXMP
#
# Elapsed time=  0.5001064651521749 s
# <------------------------------->
#
#
# Actual:  hGA4Z
# Predicted: AREd
#
# Elapsed time=  0.8684010703471682 s
# <------------------------------->
#
#
# Actual:  UWXdK
# Predicted: UWXdK
#
# Elapsed time=  0.4655809716077769 s
# <------------------------------->
#
#
# Actual:  72SZX
# Predicted: 72SZX
#
# Elapsed time=  0.268455429823526 s
# <------------------------------->
#
#
# Actual:  nWeye
# Predicted: nWeye
#
# Elapsed time=  0.464406653439443 s
# <------------------------------->
#
#
# Actual:  WWP6d
# Predicted: WWP6d
#
# Elapsed time=  0.2959741799624196 s
# <------------------------------->
#
#
# Actual:  PHPe6
# Predicted: PHPe6
#
# Elapsed time=  0.596734665565294 s
# <------------------------------->
#
#
# Actual:  Xh2dX
# Predicted: Xh2dX
#
# Elapsed time=  0.88909264420693 s
# <------------------------------->
#
#
# Actual:  KV3Ye
# Predicted: FPnF
#
# Elapsed time=  0.14221349884818912 s
# <------------------------------->
#
#
# Actual:  ZhNmP
# Predicted: aH7Q
#
# Elapsed time=  0.8344385336187232 s
# <------------------------------->
#
#
# Actual:  fhXY8
# Predicted: fhXY8
#
# Elapsed time=  0.5403801990967828 s
# <------------------------------->
#
#
# Actual:  4U7WV
# Predicted: hBeQ
#
# Elapsed time=  0.4374068516061431 s
# <------------------------------->
#
#
# Actual:  XSeWQ
# Predicted: XSeWQ
#
# Elapsed time=  0.8785270582627892 s
# <------------------------------->
#
#
# Actual:  N4KyC
# Predicted: KWG5
#
# Elapsed time=  0.37269468856655885 s
# <------------------------------->
#
#
# Actual:  SSUKa
# Predicted: SSUKa
#
# Elapsed time=  0.7854468608051454 s
# <------------------------------->
#
#
# Actual:  qm4XQ
# Predicted: WhdM
#
# Elapsed time=  0.9821658322860788 s
# <------------------------------->
#
#
# Actual:  n4VQC
# Predicted: QE58
#
# Elapsed time=  0.4402986180184282 s
# <------------------------------->
#
#
# Actual:  ZdBEP
# Predicted: 4ZVm
#
# Elapsed time=  0.6515129950662298 s
# <------------------------------->
#
#
# Actual:  BPHXG
# Predicted: BPHXG
#
# Elapsed time=  0.6616036677513354 s
# <------------------------------->
#
#
# Actual:  8VUVQ
# Predicted: VUEn
#
# Elapsed time=  0.3566093316361061 s
# <------------------------------->
#
#
# Actual:  eWAWK
# Predicted: mGqN
#
# Elapsed time=  0.44573714585485347 s
# <------------------------------->
#
#
# Actual:  EZQU6
# Predicted: F6Rn
#
# Elapsed time=  0.9546025614293222 s
# <------------------------------->
#
#
# Actual:  YyRV7
# Predicted: CQ3W
#
# Elapsed time=  0.811030574601081 s
# <------------------------------->
#
#
# Actual:  dGAUB
# Predicted: dGAUB
#
# Elapsed time=  0.2779057283500689 s
# <------------------------------->
#
#
# Actual:  E8nEM
# Predicted: 8VbY
#
# Elapsed time=  0.5099919317231708 s
# <------------------------------->
#
#
# Actual:  WqSSP
# Predicted: WqSSP
#
# Elapsed time=  0.20255795213806227 s
# <------------------------------->
#
#
# Actual:  yU7mZ
# Predicted: yU7mZ
#
# Elapsed time=  0.4558518656839289 s
# <------------------------------->
#
#
# Actual:  hhUhR
# Predicted: HZFK
#
# Elapsed time=  0.6539741257532936 s
# <------------------------------->
#
#
# Actual:  FWmKC
# Predicted: yGn7
#
# Elapsed time=  0.6798077808782144 s
# <------------------------------->
#
#
# Actual:  S7SH5
# Predicted: S7SH5
#
# Elapsed time=  0.0011396877595325483 s
# <------------------------------->
#
#
# Actual:  Q3NY2
# Predicted: Q3NY2
#
# Elapsed time=  0.6588141157080544 s
# <------------------------------->
#
#
# Actual:  nSF58
# Predicted: hEUC
#
# Elapsed time=  0.3124493319338758 s
# <------------------------------->
#
#
# Actual:  NnaWA
# Predicted: NnaWA
#
# Elapsed time=  0.4837780882687761 s
# <------------------------------->
#
#
# Actual:  QH5FB
# Predicted: 3EnY
#
# Elapsed time=  0.36043994887468955 s
# <------------------------------->
#
#
# Actual:  eRXMP
# Predicted: Cafm
#
# Elapsed time=  0.7615479170576865 s
# <------------------------------->
#
#
# Actual:  8ebCP
# Predicted: y5C8
#
# Elapsed time=  0.5916933712541308 s
# <------------------------------->
#
#
# Actual:  h6mnB
# Predicted: mSyb
#
# Elapsed time=  0.2262987985494226 s
# <------------------------------->
#
#
# Actual:  b2mS2
# Predicted: 8VXn
#
# Elapsed time=  0.4072039429332597 s
# <------------------------------->
#
#
# Actual:  PByBZ
# Predicted: PByBZ
#
# Elapsed time=  0.9050710525584107 s
# <------------------------------->
#
#
# Actual:  VKEQ4
# Predicted: VB4a
#
# Elapsed time=  0.3561189393479497 s
# <------------------------------->
#
#
# Actual:  FEQNH
# Predicted: 2EUd
#
# Elapsed time=  0.8711407099622366 s
# <------------------------------->
#
#
# Actual:  MAZ3C
# Predicted: YH6q
#
# Elapsed time=  0.5031040860008882 s
# <------------------------------->
#
#
# Actual:  ZKPRZ
# Predicted: fVNK
#
# Elapsed time=  0.6723347001143399 s
# <------------------------------->
#
#
# Actual:  RCnUP
# Predicted: f2PX
#
# Elapsed time=  0.31850845115909 s
# <------------------------------->
#
#
# Actual:  PVbVC
# Predicted: PVbVC
#
# Elapsed time=  0.42882293946760996 s
# <------------------------------->
#
#
# Actual:  EYmhS
# Predicted: EYmhS
#
# Elapsed time=  0.006566071373809601 s
# <------------------------------->
#
#
# Actual:  fZb2U
# Predicted: Vba4
#
# Elapsed time=  0.8357619258303147 s
# <------------------------------->
#
#
# Actual:  RCnUP
# Predicted: RCnUP
#
# Elapsed time=  0.7222965762315741 s
# <------------------------------->
#
#
# Actual:  qhmq5
# Predicted: 47N6
#
# Elapsed time=  0.10380177310595373 s
# <------------------------------->
#
#
# Actual:  5qPeP
# Predicted: 5qPeP
#
# Elapsed time=  0.779973097241394 s
# <------------------------------->
#
#
# Actual:  hqX3d
# Predicted: hyA5
#
# Elapsed time=  0.5012373822371572 s
# <------------------------------->
#
#
# Actual:  Nb6Uh
# Predicted: CVaM
#
# Elapsed time=  0.016856776105261706 s
# <------------------------------->
#
#
# Actual:  BPHXG
# Predicted: AQHb
#
# Elapsed time=  0.8507849562013998 s
# <------------------------------->
#
#
# Actual:  UXVCZ
# Predicted: BeGa
#
# Elapsed time=  0.2495586437805356 s
# <------------------------------->
#
#
# Actual:  VVY7V
# Predicted: BWyW
#
# Elapsed time=  0.49371320239543115 s
# <------------------------------->
#
#
# Actual:  8ebCP
# Predicted: 8ebCP
#
# Elapsed time=  0.8318489195379404 s
# <------------------------------->
#
#
# Actual:  KCPne
# Predicted: RYqU
#
# Elapsed time=  0.7092280830159757 s
# <------------------------------->
#
#
# Actual:  SPKUN
# Predicted: SPKUN
#
# Elapsed time=  0.5975235751781075 s
# <------------------------------->
#
#
# Actual:  UWXdK
# Predicted: H83B
#
# Elapsed time=  0.009454777097784972 s
# <------------------------------->
#
#
# Actual:  eHA6K
# Predicted: eHA6K
#
# Elapsed time=  0.43211778818959057 s
# <------------------------------->
#
#
# Actual:  ddVUS
# Predicted: ddVUS
#
# Elapsed time=  0.7356205206274856 s
# <------------------------------->
#
#
# Actual:  SVCY2
# Predicted: yhmA
#
# Elapsed time=  0.3678264652587867 s
# <------------------------------->
# Total number of CAPTCHAS broken:  214
# Total number of CAPTCHAS attempted:  500
# Total time taken=  161.91428742920212 s
# Accuracy=  42.8
