# %%
import os

# %%
os.listdir('test/')
# Out:
# ['9533_M8CP.jpg',
#  '9538_6F6Y.jpg',
#  '9866_76CE.jpg',
#  '9956_HKPK.jpg',
#  '9568_K776.jpg',
#  '9738_YE5H.jpg',
#  '9615_K7R6.jpg',
#  '9827_RPME.jpg',
#  '9576_SGY5.jpg',
#  '9971_WFMK.jpg',
#  '9764_RFJF.jpg',
#  '9634_3CJA.jpg',
#  '9982_ESJ4.jpg',
#  '9678_MQRJ.jpg',
#  '9897_KGF8.jpg',
#  '9904_FXRQ.jpg',
#  '9679_5MWG.jpg',
#  '9940_EKHC.jpg',
#  '9886_7N36.jpg',
#  '9662_3SW5.jpg',
#  '9888_43AJ.jpg',
#  '9953_5AQQ.jpg',
#  '9766_N7PX.jpg',
#  '9811_8WHP.jpg',
#  '9721_XRYA.jpg',
#  '9864_33ER.jpg',
#  '9917_H75H.jpg',
#  '9930_BSJS.jpg',
#  '9789_F3KN.jpg',
#  '9505_CMP4.jpg',
#  '9523_CANK.jpg',
#  '9518_R8GG.jpg',
#  '9900_GAMN.jpg',
#  '9671_8YPH.jpg',
#  '9504_7APG.jpg',
#  '9688_4KW5.jpg',
#  '9993_GGQX.jpg',
#  '9657_QG8X.jpg',
#  '9977_EH8F.jpg',
#  '9846_SFY6.jpg',
#  '9562_QF6Q.jpg',
#  '9554_G4RM.jpg',
#  '9740_Q4B8.jpg',
#  '9718_BBW6.jpg',
#  '9825_YK54.jpg',
#  '9775_SJXE.jpg',
#  '9967_7J7A.jpg',
#  '9771_CMKX.jpg',
#  '9986_K7Q5.jpg',
#  '9961_7GRH.jpg',
# ...

# %%
for filename in os.listdir('train_/'):
    filename_1= filename.split('_')
    final = filename_1[1]

    print(final)
    os.rename(os.path.join('train_/',filename),os.path.join('train_',final))
# Out:
# E3YY.jpg
# GMHR.jpg
# HB5Y.jpg
# GKFP.jpg
# 57GR.jpg
# JSJP.jpg
# WCBC.jpg
# RG7S.jpg
# ARHJ.jpg
# 5JNB.jpg
# GEG8.jpg
# QQCS.jpg
# YECB.jpg
# 5NHE.jpg
# C8GB.jpg
# JGRM.jpg
# WS58.jpg
# 3NR4.jpg
# SKJ6.jpg
# YAKY.jpg
# RGHK.jpg
# YNAR.jpg
# X44B.jpg
# YPPS.jpg
# RKFE.jpg
# N5PX.jpg
# SCH7.jpg
# C38A.jpg
# JP3J.jpg
# 444K.jpg
# YNMB.jpg
# JCYG.jpg
# G86E.jpg
# 34E5.jpg
# QM4F.jpg
# 5NP7.jpg
# Y648.jpg
# YX8C.jpg
# Q675.jpg
# YFRF.jpg
# 3KEH.jpg
# 4GEC.jpg
# QX75.jpg
# N5K4.jpg
# MAY7.jpg
# 3RY5.jpg
# GJ5M.jpg
# 7WX6.jpg
# P7P5.jpg
# 4MC3.jpg
# 3SGM.jpg
# 5EQ5.jpg
# 7G85.jpg
# AGSQ.jpg
# XJWC.jpg
# 4SW8.jpg
# SGA7.jpg
# YYWK.jpg
# 4BAX.jpg
# XR3C.jpg
# SSG8.jpg
# SS6R.jpg
# NQ38.jpg
# 7SRM.jpg
# Y5SB.jpg
# 47QG.jpg
# KQFC.jpg
# 5BJX.jpg
# W3N8.jpg
# EEEQ.jpg
# B5JW.jpg
# SK65.jpg
# 87SY.jpg
# 44KX.jpg
# 4ABW.jpg
# BH83.jpg
# 3SES.jpg
# 743Q.jpg
# 6RSG.jpg
# RKS4.jpg
# Q3N8.jpg
# F8W5.jpg
# MXBY.jpg
# JWNE.jpg
# Q3C6.jpg
# C5NY.jpg
# 6NNA.jpg
# YGMS.jpg
# 7PRK.jpg
# SE3E.jpg
# ...

# %%
for filename in os.listdir('sina//'):
    name_len = len(os.path.splitext(filename)[0])
    try:
        os.mkdir("sina/{}".format(str(name_len)))
    except FileExistsError:
        pass
    os.rename("sina/{}".format(filename), "sina/{}/{}".format(name_len,filename))
